# %%
from CARTO_Tool import Carto
carto=Carto()
# Out:
# could not initialize
# choose your file from the dialogue
# F:/New folder
# options:  {0: '1-1-SR_Rigth_Atrium', 1: '1-AF_Right_Atrium', 2: '2-1-2-1-ReSR_LA_No_Filtered', 3: '2-1-2-ReSR_LA_No_Filtered', 4: '2-1-3-MApa_Nueva_ref_No_Valido', 5: '2-1-Mapa_No_Valido', 6: '2-1-SR_LA_No_Filtered', 7: '2-1-SR_Left_Atrium', 8: '2-1-SR_PsAF_3Extra', 9: '2-AF_Left_Atrium'}
# choose your file with its index passing to set_cat_value method
# 8
# 2-1-SR_PsAF_3Extra 8

# %%
""" or alternatively you can initialize the module with the path """
#carto=Carto("path to the folder")
# Out:
# ' or alternatively you can initialize the module with the path '

# %%
"""list of all map names inside the folder"""
carto.geting_categories()
# Out:
# ['1-1-SR_Rigth_Atrium',
#  '1-AF_Right_Atrium',
#  '2-1-2-1-ReSR_LA_No_Filtered',
#  '2-1-2-ReSR_LA_No_Filtered',
#  '2-1-3-MApa_Nueva_ref_No_Valido',
#  '2-1-Mapa_No_Valido',
#  '2-1-SR_LA_No_Filtered',
#  '2-1-SR_Left_Atrium',
#  '2-1-SR_PsAF_3Extra',
#  '2-AF_Left_Atrium']

# %%
"""summary of all files inside the folder"""
carto.sorted_file_types_with_number()
# Out:
# {'1-1-SR_Rigth_Atrium.mesh': 1,
#  '1-1-SR_Rigth_Atrium_car.txt': 1,
#  '1-1-SR_Rigth_Atrium_DEC_CONNECTOR_Eleclectrode_Positions_.txt': 208,
#  '1-1-SR_Rigth_Atrium_DEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 208,
#  '1-1-SR_Rigth_Atrium_ECG_Export_.txt': 208,
#  '1-1-SR_Rigth_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_.txt': 208,
#  '1-1-SR_Rigth_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 208,
#  '1-1-SR_Rigth_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_.txt': 208,
#  '1-1-SR_Rigth_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 208,
#  '1-1-SR_Rigth_Atrium_MEC_CONNECTOR_Eleclectrode_Positions_.txt': 208,
#  '1-1-SR_Rigth_Atrium_MEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 208,
#  '1-1-SR_Rigth_Atrium_MEC_CONNECTOR_Sensor_Positions_.txt': 208,
#  '1-1-SR_Rigth_Atrium_MEC_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 208,
#  '1-1-SR_Rigth_Atrium_P_Point_Export.xml': 848,
#  '1-1-SR_Rigth_Atrium_Points_Export.xml': 1,
#  '1-AF_Right_Atrium.mesh': 1,
#  '1-AF_Right_Atrium_car.txt': 1,
#  '1-AF_Right_Atrium_ECG_Export_.txt': 556,
#  '1-AF_Right_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_.txt': 556,
#  '1-AF_Right_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 556,
#  '1-AF_Right_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_.txt': 556,
#  '1-AF_Right_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 556,
#  '1-AF_Right_Atrium_P_Point_Export.xml': 1673,
#  '1-AF_Right_Atrium_Points_Export.xml': 1,
#  '2-1-1-1-RequemarAI.mesh': 1,
#  '2-1-1-1-RequemarAI_car.txt': 1,
#  '2-1-1-1-RequemarAI_Points_Export.xml': 1,
#  '2-1-1-quemarAI.mesh': 1,
#  '2-1-1-quemarAI_car.txt': 1,
#  '2-1-1-quemarAI_Points_Export.xml': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered.mesh': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_car.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_DEC_CONNECTOR_Eleclectrode_Positions_.txt': 41,
#  '2-1-2-1-ReSR_LA_No_Filtered_DEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 41,
#  '2-1-2-1-ReSR_LA_No_Filtered_DEC_CONNECTOR_Sensor_Positions_.txt': 15,
#  '2-1-2-1-ReSR_LA_No_Filtered_DEC_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 15,
#  '2-1-2-1-ReSR_LA_No_Filtered_ECG_Export_.txt': 44,
#  '2-1-2-1-ReSR_LA_No_Filtered_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_.txt': 44,
#  '2-1-2-1-ReSR_LA_No_Filtered_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 44,
#  '2-1-2-1-ReSR_LA_No_Filtered_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_.txt': 44,
#  '2-1-2-1-ReSR_LA_No_Filtered_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 44,
#  '2-1-2-1-ReSR_LA_No_Filtered_MEC_CONNECTOR_Eleclectrode_Positions_.txt': 44,
#  '2-1-2-1-ReSR_LA_No_Filtered_MEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 44,
#  '2-1-2-1-ReSR_LA_No_Filtered_MEC_CONNECTOR_Sensor_Positions_.txt': 44,
#  '2-1-2-1-ReSR_LA_No_Filtered_MEC_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 44,
#  '2-1-2-1-ReSR_LA_No_Filtered_P_Point_Export.xml': 305,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7167_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7168_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7169_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7170_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7171_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7172_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7173_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7174_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7175_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7176_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7177_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7178_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7179_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7180_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_P7181_ContactForce.txt': 1,
#  '2-1-2-1-ReSR_LA_No_Filtered_Points_Export.xml': 1,
#  '2-1-2-ReSR_LA_No_Filtered.mesh': 1,
#  '2-1-2-ReSR_LA_No_Filtered_car.txt': 1,
#  '2-1-2-ReSR_LA_No_Filtered_DEC_CONNECTOR_Eleclectrode_Positions_.txt': 26,
#  '2-1-2-ReSR_LA_No_Filtered_DEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 26,
#  '2-1-2-ReSR_LA_No_Filtered_ECG_Export_.txt': 29,
#  '2-1-2-ReSR_LA_No_Filtered_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_.txt': 29,
#  '2-1-2-ReSR_LA_No_Filtered_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 29,
#  '2-1-2-ReSR_LA_No_Filtered_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_.txt': 29,
#  '2-1-2-ReSR_LA_No_Filtered_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 29,
#  '2-1-2-ReSR_LA_No_Filtered_MEC_CONNECTOR_Eleclectrode_Positions_.txt': 29,
#  '2-1-2-ReSR_LA_No_Filtered_MEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 29,
#  '2-1-2-ReSR_LA_No_Filtered_MEC_CONNECTOR_Sensor_Positions_.txt': 29,
#  '2-1-2-ReSR_LA_No_Filtered_MEC_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 29,
#  '2-1-2-ReSR_LA_No_Filtered_P_Point_Export.xml': 290,
#  '2-1-2-ReSR_LA_No_Filtered_Points_Export.xml': 1,
#  '2-1-3-MApa_Nueva_ref_No_Valido.mesh': 1,
#  '2-1-3-MApa_Nueva_ref_No_Valido_car.txt': 1,
#  '2-1-3-MApa_Nueva_ref_No_Valido_DEC_CONNECTOR_Eleclectrode_Positions_.txt': 589,
#  '2-1-3-MApa_Nueva_ref_No_Valido_DEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 589,
#  '2-1-3-MApa_Nueva_ref_No_Valido_ECG_Export_.txt': 752,
#  '2-1-3-MApa_Nueva_ref_No_Valido_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_.txt': 752,
#  '2-1-3-MApa_Nueva_ref_No_Valido_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 752,
#  '2-1-3-MApa_Nueva_ref_No_Valido_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_.txt': 752,
#  '2-1-3-MApa_Nueva_ref_No_Valido_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 752,
#  '2-1-3-MApa_Nueva_ref_No_Valido_MEC_CONNECTOR_Eleclectrode_Positions_.txt': 752,
#  '2-1-3-MApa_Nueva_ref_No_Valido_MEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 752,
#  '2-1-3-MApa_Nueva_ref_No_Valido_MEC_CONNECTOR_Sensor_Positions_.txt': 752,
#  '2-1-3-MApa_Nueva_ref_No_Valido_MEC_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 752,
#  '2-1-3-MApa_Nueva_ref_No_Valido_P_Point_Export.xml': 3461,
#  '2-1-3-MApa_Nueva_ref_No_Valido_Points_Export.xml': 1,
#  '2-1-Mapa_No_Valido.mesh': 1,
#  '2-1-Mapa_No_Valido_car.txt': 1,
#  '2-1-Mapa_No_Valido_DEC_CONNECTOR_Eleclectrode_Positions_.txt': 482,
#  '2-1-Mapa_No_Valido_DEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 482,
#  '2-1-Mapa_No_Valido_ECG_Export_.txt': 653,
#  '2-1-Mapa_No_Valido_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_.txt': 653,
#  '2-1-Mapa_No_Valido_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 653,
#  '2-1-Mapa_No_Valido_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_.txt': 653,
#  '2-1-Mapa_No_Valido_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 653,
#  '2-1-Mapa_No_Valido_MEC_CONNECTOR_Eleclectrode_Positions_.txt': 653,
#  '2-1-Mapa_No_Valido_MEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 653,
#  '2-1-Mapa_No_Valido_MEC_CONNECTOR_Sensor_Positions_.txt': 653,
#  '2-1-Mapa_No_Valido_MEC_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 653,
#  '2-1-Mapa_No_Valido_P_Point_Export.xml': 2035,
#  '2-1-Mapa_No_Valido_Points_Export.xml': 1,
#  '2-1-SR_LA_No_Filtered.mesh': 1,
#  '2-1-SR_LA_No_Filtered_car.txt': 1,
#  '2-1-SR_LA_No_Filtered_DEC_CONNECTOR_Eleclectrode_Positions_.txt': 845,
#  '2-1-SR_LA_No_Filtered_DEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 845,
#  '2-1-SR_LA_No_Filtered_ECG_Export_.txt': 1055,
#  '2-1-SR_LA_No_Filtered_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_.txt': 1055,
#  '2-1-SR_LA_No_Filtered_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 1055,
#  '2-1-SR_LA_No_Filtered_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_.txt': 1055,
#  '2-1-SR_LA_No_Filtered_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 1055,
#  '2-1-SR_LA_No_Filtered_MEC_CONNECTOR_Eleclectrode_Positions_.txt': 1055,
#  '2-1-SR_LA_No_Filtered_MEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 1055,
#  '2-1-SR_LA_No_Filtered_MEC_CONNECTOR_Sensor_Positions_.txt': 1055,
#  '2-1-SR_LA_No_Filtered_MEC_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 1055,
#  '2-1-SR_LA_No_Filtered_P_Point_Export.xml': 7255,
#  '2-1-SR_LA_No_Filtered_Points_Export.xml': 1,
#  '2-1-SR_Left_Atrium.mesh': 1,
#  '2-1-SR_Left_Atrium_car.txt': 1,
#  '2-1-SR_Left_Atrium_DEC_CONNECTOR_Eleclectrode_Positions_.txt': 674,
#  '2-1-SR_Left_Atrium_DEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 674,
#  '2-1-SR_Left_Atrium_ECG_Export_.txt': 834,
#  '2-1-SR_Left_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_.txt': 834,
#  '2-1-SR_Left_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 834,
#  '2-1-SR_Left_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_.txt': 834,
#  '2-1-SR_Left_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 834,
#  '2-1-SR_Left_Atrium_MEC_CONNECTOR_Eleclectrode_Positions_.txt': 834,
#  '2-1-SR_Left_Atrium_MEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 834,
#  '2-1-SR_Left_Atrium_MEC_CONNECTOR_Sensor_Positions_.txt': 834,
#  '2-1-SR_Left_Atrium_MEC_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 834,
#  '2-1-SR_Left_Atrium_P_Point_Export.xml': 3657,
#  '2-1-SR_Left_Atrium_Points_Export.xml': 1,
#  '2-1-SR_PsAF_3Extra.mesh': 1,
#  '2-1-SR_PsAF_3Extra_car.txt': 1,
#  '2-1-SR_PsAF_3Extra_DEC_CONNECTOR_Eleclectrode_Positions_.txt': 26,
#  '2-1-SR_PsAF_3Extra_DEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 26,
#  '2-1-SR_PsAF_3Extra_ECG_Export_.txt': 29,
#  '2-1-SR_PsAF_3Extra_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_.txt': 29,
#  '2-1-SR_PsAF_3Extra_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 29,
#  '2-1-SR_PsAF_3Extra_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_.txt': 29,
#  '2-1-SR_PsAF_3Extra_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 29,
#  '2-1-SR_PsAF_3Extra_MEC_CONNECTOR_Eleclectrode_Positions_.txt': 29,
#  '2-1-SR_PsAF_3Extra_MEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 29,
#  '2-1-SR_PsAF_3Extra_MEC_CONNECTOR_Sensor_Positions_.txt': 29,
#  '2-1-SR_PsAF_3Extra_MEC_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 29,
#  '2-1-SR_PsAF_3Extra_P_Point_Export.xml': 284,
#  '2-1-SR_PsAF_3Extra_Points_Export.xml': 1,
#  '2-AF_Left_Atrium.mesh': 1,
#  '2-AF_Left_Atrium_car.txt': 1,
#  '2-AF_Left_Atrium_DEC_CONNECTOR_Eleclectrode_Positions_.txt': 670,
#  '2-AF_Left_Atrium_DEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 670,
#  '2-AF_Left_Atrium_ECG_Export_.txt': 670,
#  '2-AF_Left_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_.txt': 670,
#  '2-AF_Left_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 670,
#  '2-AF_Left_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_.txt': 670,
#  '2-AF_Left_Atrium_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 670,
#  '2-AF_Left_Atrium_MEC_CONNECTOR_Eleclectrode_Positions_.txt': 21,
#  '2-AF_Left_Atrium_MEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt': 24,
#  '2-AF_Left_Atrium_MEC_CONNECTOR_Sensor_Positions_.txt': 643,
#  '2-AF_Left_Atrium_MEC_CONNECTOR_Sensor_Positions_OnAnnotation_.txt': 643,
#  '2-AF_Left_Atrium_P_Point_Export.xml': 2286,
#  '2-AF_Left_Atrium_Points_Export.xml': 1,
#  '3-ev_car.txt': 1,
#  '3-ev_Points_Export.xml': 1,
#  'Aorta.mesh': 1,
#  'APAData.txt': 1,
#  'ContactForceInRF_2-1-1-1-RequemarAI_.txt': 64,
#  'ContactForceInRF_2-1-2-1-ReSR_LA_No_Filtered_.txt': 2,
#  'Esofa.mesh': 1,
#  'Export_Study-1-10_24_2024-15-29-43.zip': 1,
#  'LA.mesh': 1,
#  'LAWT.mesh': 1,
#  'LAWT.vtk': 1,
#  'LA_Endo.vtk': 1,
#  'LA_Epi.vtk': 1,
#  'LA_Print_esfogao.mesh': 1,
#  'LV.mesh': 1,
#  'Orejuela.mesh': 1,
#  'Orejuela.vtk': 1,
#  'PA.mesh': 1,
#  'RA.mesh': 1,
#  'RA.vtk': 1,
#  'RF_2-1-1-1-RequemarAI_.txt': 64,
#  'RF_2-1-2-1-ReSR_LA_No_Filtered_.txt': 2,
#  'RF_CARTO_TO_ABLATOR_SESSIONS_MAPPING.txt': 1,
#  'RV.mesh': 1,
#  'Study 1 10_24_2024 15-29-43.xml': 1,
#  'TemperaturesInRF_2-1-1-1-RequemarAI_.txt': 64,
#  'TemperaturesInRF_2-1-2-1-ReSR_LA_No_Filtered_.txt': 2,
#  'Version.txt': 1}

# %%
"""selecting map name manually based on the map name´s index of the output of carto.geting_categories()"""
carto.set_cat_value(5)

# %%
"""car.txt file regarding to the map that is selected"""
carto.Car_file()
# Out:
#      A  B     C  D         E         F        G          H          I  \
# 0    P  0   407  0   1.83166   1.95644  88.6631  -0.864717  -0.463506
# 1    P  0   408  0  -5.13522  -1.49466  86.8315  -0.877666  -0.399612
# 2    P  0   409  0  0.930086  -10.6205  81.1443  -0.837493   0.506549
# 3    P  0   410  0  -5.58346  -6.54973  83.2922  -0.792137   0.511917
# 4    P  0   411  0  -15.3675  -12.8436  77.0439   0.418842   0.820203
# ..  .. ..   ... ..       ...       ...      ...        ...        ...
# 279  P  0  7161  0  -19.7263   -52.065  79.0883  -0.388454   0.854807
# 280  P  0  7162  0  -22.0735  -46.8577  77.3007  -0.394975   0.883265
# 281  P  0  7164  0  -29.3471  -43.8266  75.5485   0.946954   0.319509
# 282  P  0  7165  0  -32.5567  -34.0192  74.6287   0.757994  -0.649945
# 283  P  0  7166  0  -28.1375  -38.0366  75.0998    0.71631   -0.69026
#
#              J  ...    AT AU   AV      AW     AX        AY AZ         A[ A\  \
# 0    -0.193461  ...  2000  1  N\A  -10000      2   1.51455  0  0.0965015  8
# 1    -0.264598  ...  2000  1  N\A  -10000     54  0.697583  0  0.0219495  8
# 2     0.204975  ...  2000  1  N\A  -10000     14   0.50997  0   0.113495  8
# 3     0.332356  ...  2000  1  N\A  -10000  10000  0.524106  0     -10000  8
# 4     0.389664  ...  2000  1  N\A  -10000      4  0.601066  0   0.153477  8
# ..         ...  ...   ... ..  ...     ...    ...       ... ..        ... ..
# 279  -0.344106  ...  2000  0  N\A  -10000      5  0.565332  0   0.314851  8
# 280  -0.252661  ...  2000  1  N\A  -10000      5  0.509589  0    1.39997  8
# 281  0.0345284  ...  2000  1  N\A  -10000      3  0.479605  0    1.46517  8
# 282  0.0549275  ...  2000  0  N\A  -10000      2  0.489699  0   0.392356  8
# 283   0.102179  ...  2000  1  N\A  -10000      5  0.517875  0   0.598759  8
#
#          A]
# 0    -10000
# 1    -10000
# 2    -10000
# 3    -10000
# 4    -10000
# ..      ...
# 279  -10000
# 280  -10000
# 281  -10000
# 282  -10000
# 283  -10000
#
# [284 rows x 55 columns]

# %%
"""extracting usefull data from the main .xml file regarding to label colors"""
carto.extracting_color_coding()
# Out:
# [{'Radius': '2',
#   'Color': '1 1 1 1',
#   'Full_Name': 'None',
#   'Short_Name': 'None',
#   'Tag ID': '4'},
#  {'Radius': '2',
#   'Color': '0.298039 0.239216 0.819608 1',
#   'Full_Name': 'LSPV OS',
#   'Short_Name': 'LSPV OS',
#   'Tag ID': '201'},
#  {'Radius': '2',
#   'Color': '0.517647 0 0 1',
#   'Full_Name': 'Ablation',
#   'Short_Name': 'ABL',
#   'Tag ID': '9'},
#  {'Radius': '2',
#   'Color': '0.937255 0.709804 0.129412 1',
#   'Full_Name': 'His',
#   'Short_Name': 'HIS',
#   'Tag ID': '5'},
#  {'Radius': '2',
#   'Color': '0.776471 0.776471 0 1',
#   'Full_Name': 'Pacing Site',
#   'Short_Name': 'PS',
#   'Tag ID': '6'},
#  {'Radius': '2',
#   'Color': '0.501961 0 1 1',
#   'Full_Name': 'RMPV_AC',
#   'Short_Name': 'RMPV_AC',
#   'Tag ID': '312'},
#  {'Radius': '2',
#   'Color': '0 0.776471 0.776471 1',
#   'Full_Name': 'Double Potential',
#   'Short_Name': 'DP',
#   'Tag ID': '7'},
#  {'Radius': '2',
#   'Color': '1 0.776471 1 1',
#   'Full_Name': 'Fragmented Signal',
#   'Short_Name': 'FS',
#   'Tag ID': '8'},
#  {'Radius': '2',
#   'Color': '0.0235294 0.839216 0.819608 1',
#   'Full_Name': 'LIPV OS',
#   'Short_Name': 'LIPV OS',
#   'Tag ID': '200'},
#  {'Radius': '2',
#   'Color': '0.419608 0.388235 0.388235 1',
#   'Full_Name': 'Scar',
#   'Short_Name': 'SCR',
#   'Tag ID': '10'},
#  {'Radius': '2',
#   'Color': '0.764706 0.768627 0.0313726 1',
#   'Full_Name': 'RIPV OS',
#   'Short_Name': 'RIPV OS',
#   'Tag ID': '202'},
#  {'Radius': '2',
#   'Color': '0.756863 0.929412 0.647059 1',
#   'Full_Name': 'Location Only',
#   'Short_Name': 'LO',
#   'Tag ID': '11'},
#  {'Radius': '2',
#   'Color': '0.603922 0.309804 0.0235294 1',
#   'Full_Name': 'RSPV OS',
#   'Short_Name': 'RSPV OS',
#   'Tag ID': '203'},
#  {'Radius': '2',
#   'Color': '0.752941 1 1 1',
#   'Full_Name': 'LIPV',
#   'Short_Name': 'LIPV',
#   'Tag ID': '100'},
#  {'Radius': '2',
#   'Color': '0.619608 0.584314 0.968627 1',
#   'Full_Name': 'LSPV',
#   'Short_Name': 'LSPV',
#   'Tag ID': '101'},
#  {'Radius': '2',
#   'Color': '1 1 0.501961 1',
#   'Full_Name': 'RIPV',
#   'Short_Name': 'RIPV',
#   'Tag ID': '102'},
#  {'Radius': '2',
#   'Color': '0 0.501961 0.752941 1',
#   'Full_Name': 'Used Frame',
#   'Short_Name': 'UF',
#   'Tag ID': '301'},
#  {'Radius': '2',
#   'Color': '1 0.501961 0 1',
#   'Full_Name': 'RSPV',
#   'Short_Name': 'RSPV',
#   'Tag ID': '103'},
#  {'Radius': '2',
#   'Color': '0.603922 0.0235294 0.47451 1',
#   'Full_Name': 'IVC OS',
#   'Short_Name': 'IVC OS',
#   'Tag ID': '204'},
#  {'Radius': '2',
#   'Color': '0.0352941 0.588235 0.235294 1',
#   'Full_Name': 'SVC OS',
#   'Short_Name': 'SVC OS',
#   'Tag ID': '205'},
#  {'Radius': '2',
#   'Color': '0 0 1 1',
#   'Full_Name': 'End of Sheath',
#   'Short_Name': 'EOS',
#   'Tag ID': '13'},
#  {'Radius': '2',
#   'Color': '0.92549 0.784314 0.788235 1',
#   'Full_Name': 'CS OS',
#   'Short_Name': 'CS OS',
#   'Tag ID': '206'},
#  {'Radius': '2',
#   'Color': '0.517647 0 0 1',
#   'Full_Name': 'QMODE+ Ablation',
#   'Short_Name': 'QM+',
#   'Tag ID': '14'},
#  {'Radius': '2',
#   'Color': '1 1 1 1',
#   'Full_Name': 'Mitral Annulus',
#   'Short_Name': 'MA',
#   'Tag ID': '104'},
#  {'Radius': '2',
#   'Color': '0.337255 0.411765 0.356863 1',
#   'Full_Name': 'ESOPHAGUS',
#   'Short_Name': 'ESO',
#   'Tag ID': '311'},
#  {'Radius': '2',
#   'Color': '0 0.501961 1 1',
#   'Full_Name': 'Tricuspid Annulus',
#   'Short_Name': 'TA',
#   'Tag ID': '105'},
#  {'Radius': '1',
#   'Color': '0 0.501961 0 1',
#   'Full_Name': 'Complex.Frac',
#   'Short_Name': 'C.Frac',
#   'Tag ID': '51'},
#  {'Radius': '2',
#   'Color': '0.337255 0.411765 0.356863 1',
#   'Full_Name': 'ACESOPHAGUS',
#   'Short_Name': 'ACESOPH',
#   'Tag ID': '308'},
#  {'Radius': '2',
#   'Color': '0.501961 1 1 1',
#   'Full_Name': 'CLIP',
#   'Short_Name': 'CLIP',
#   'Tag ID': '500'},
#  {'Radius': '2',
#   'Color': '0.517647 0 0 1',
#   'Full_Name': 'RF Balloon Ablation',
#   'Short_Name': 'RF Ball',
#   'Tag ID': '15'},
#  {'Radius': '2',
#   'Color': '0.501961 1 1 1',
#   'Full_Name': 'New Frame',
#   'Short_Name': 'NF',
#   'Tag ID': '300'},
#  {'Radius': '2',
#   'Color': '0.501961 0.501961 0 1',
#   'Full_Name': 'LA_AC',
#   'Short_Name': 'LA_AC',
#   'Tag ID': '302'},
#  {'Radius': '2',
#   'Color': '0.25098 0 0.25098 1',
#   'Full_Name': 'LAA_AC',
#   'Short_Name': 'LAA_AC',
#   'Tag ID': '303'},
#  {'Radius': '2',
#   'Color': '0.752941 1 1 1',
#   'Full_Name': 'LIPV_AC',
#   'Short_Name': 'LIPV_AC',
#   'Tag ID': '304'},
#  {'Radius': '2',
#   'Color': '0.619608 0.584314 0.968627 1',
#   'Full_Name': 'LSPV_AC',
#   'Short_Name': 'LSPV_AC',
#   'Tag ID': '305'},
#  {'Radius': '2',
#   'Color': '1 1 0.501961 1',
#   'Full_Name': 'RIPV_AC',
#   'Short_Name': 'RIPV_AC',
#   'Tag ID': '306'},
#  {'Radius': '2',
#   'Color': '1 0.501961 0 1',
#   'Full_Name': 'RSPV_AC',
#   'Short_Name': 'RSPV_AC',
#   'Tag ID': '307'},
#  {'Radius': '2',
#   'Color': '0.501961 0.501961 0 1',
#   'Full_Name': 'LA',
#   'Short_Name': 'LA',
#   'Tag ID': '309'},
#  {'Radius': '2',
#   'Color': '0.25098 0 0.25098 1',
#   'Full_Name': 'LAA',
#   'Short_Name': 'LAA',
#   'Tag ID': '310'},
#  {'Radius': '2',
#   'Color': '1 0.501961 0 1',
#   'Full_Name': 'Neg',
#   'Short_Name': 'Neg',
#   'Tag ID': '25'},
#  {'Radius': '2',
#   'Color': '0 1 0 1',
#   'Full_Name': 'Pos',
#   'Short_Name': 'Pos',
#   'Tag ID': '26'},
#  {'Radius': '2',
#   'Color': '0.501961 0 1 1',
#   'Full_Name': 'RMPV',
#   'Short_Name': 'RMPV',
#   'Tag ID': '313'},
#  {'Radius': '2',
#   'Color': '0 1 0 1',
#   'Full_Name': 'LCPV_AC',
#   'Short_Name': 'LCPV_AC',
#   'Tag ID': '314'},
#  {'Radius': '2',
#   'Color': '0 1 0 1',
#   'Full_Name': 'LCPV',
#   'Short_Name': 'LCPV',
#   'Tag ID': '315'},
#  {'Radius': '2',
#   'Color': '0.192157 0.0823529 0.278431 1',
#   'Full_Name': 'PF Ablation',
#   'Short_Name': 'PFA ABL',
#   'Tag ID': '16'},
#  {'Radius': '2',
#   'Color': '0 0.501961 0.25098 1',
#   'Full_Name': 'Doubts',
#   'Short_Name': 'Dou',
#   'Tag ID': '27'}]

# %%
"""extracting usefull data from the main .xml file regarding to label colors but only triple extra labels"""
carto.extracting_color_coding(triple=True)
# Out:
# [{'Radius': '2',
#   'Color': '1 0.501961 0 1',
#   'Full_Name': 'Neg',
#   'Short_Name': 'Neg',
#   'Tag ID': '25'},
#  {'Radius': '2',
#   'Color': '0 1 0 1',
#   'Full_Name': 'Pos',
#   'Short_Name': 'Pos',
#   'Tag ID': '26'}]

# %%
"""extracting only usefull data from the car file and labeling them based on carto.extracting_color_coding()
 output, all the labels that exist in the main .xml file"""
carto.car_extract()
# Out:
#     label_color point number   sample         x         y        z
# 0           Neg          407  4836472   1.83166   1.95644  88.6631
# 1           Neg          408  4836472  -5.13522  -1.49466  86.8315
# 2           Neg          409  4836472  0.930086  -10.6205  81.1443
# 3           Neg          410  4836472  -5.58346  -6.54973  83.2922
# 4           Pos          411  4836472  -15.3675  -12.8436  77.0439
# ..          ...          ...      ...       ...       ...      ...
# 279         Neg         7161  5864610  -19.7263   -52.065  79.0883
# 280         Neg         7162  5864610  -22.0735  -46.8577  77.3007
# 281         Neg         7164  5864610  -29.3471  -43.8266  75.5485
# 282         Neg         7165  5864610  -32.5567  -34.0192  74.6287
# 283         Neg         7166  5864610  -28.1375  -38.0366  75.0998
#
# [284 rows x 6 columns]

# %%
"""extracting only usefull data from the car file and labeling them based on carto.extracting_color_coding()
 output, data that are not labeled as green or orange or positive or negative will not be shown"""
carto.car_extract(triple=True)
# Out:
#     label_color point number   sample         x         y        z
# 0           Neg          407  4836472   1.83166   1.95644  88.6631
# 1           Neg          408  4836472  -5.13522  -1.49466  86.8315
# 2           Neg          409  4836472  0.930086  -10.6205  81.1443
# 3           Neg          410  4836472  -5.58346  -6.54973  83.2922
# 4           Pos          411  4836472  -15.3675  -12.8436  77.0439
# ..          ...          ...      ...       ...       ...      ...
# 279         Neg         7161  5864610  -19.7263   -52.065  79.0883
# 280         Neg         7162  5864610  -22.0735  -46.8577  77.3007
# 281         Neg         7164  5864610  -29.3471  -43.8266  75.5485
# 282         Neg         7165  5864610  -32.5567  -34.0192  74.6287
# 283         Neg         7166  5864610  -28.1375  -38.0366  75.0998
#
# [284 rows x 6 columns]

# %%
"""the file_number is added after having been extracted from [map_name]_P[point_number]_Point_Export.xml"""
carto.electrodes()
# Out:
#     label_color   sample point number  \
# 0           Neg  4836472          407
# 1           Neg  4836472          408
# 2           Neg  4836472          409
# 3           Neg  4836472          410
# 4           Pos  4836472          411
# ..          ...      ...          ...
# 279         Neg  5864610         7161
# 280         Neg  5864610         7162
# 281         Neg  5864610         7164
# 282         Neg  5864610         7165
# 283         Neg  5864610         7166
#
#                                    file_number unipolar    bipolar         x  \
# 0    2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt    20A_1    20A_1-2   1.83166
# 1    2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt    20A_3    20A_3-4  -5.13522
# 2    2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt    20A_5    20A_5-6  0.930086
# 3    2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt    20A_7    20A_7-8  -5.58346
# 4    2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt    20A_9   20A_9-10  -15.3675
# ..                                         ...      ...        ...       ...
# 279  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt   20A_10   20A_9-10  -19.7263
# 280  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt   20A_11  20A_11-12  -22.0735
# 281  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt   20A_15  20A_15-16  -29.3471
# 282  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt   20A_18  20A_17-18  -32.5567
# 283  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt   20A_19  20A_19-20  -28.1375
#
#             y        z  refference_chanel
# 0     1.95644  88.6631  MCC_Abl_BiPolar_1
# 1    -1.49466  86.8315  MCC_Abl_BiPolar_1
# 2    -10.6205  81.1443  MCC_Abl_BiPolar_1
# 3    -6.54973  83.2922  MCC_Abl_BiPolar_1
# 4    -12.8436  77.0439  MCC_Abl_BiPolar_1
# ..        ...      ...                ...
# 279   -52.065  79.0883  MCC_Abl_BiPolar_1
# 280  -46.8577  77.3007  MCC_Abl_BiPolar_1
# 281  -43.8266  75.5485  MCC_Abl_BiPolar_1
# 282  -34.0192  74.6287  MCC_Abl_BiPolar_1
# 283  -38.0366  75.0998  MCC_Abl_BiPolar_1
#
# [284 rows x 10 columns]

# %%
"""extracting the signals"""
sig=carto.Signals()
sig
# Out:
# 0.18945026397705078
# 0.23933887481689453
# 0.22052741050720215
# 0.20967769622802734
# 0.20743417739868164
# 0.18949294090270996
# 0.19148516654968262
# 0.19515228271484375
# 0.18550372123718262
# 0.1828908920288086
# 0.1795196533203125
# 0.18051457405090332
# 0.17952275276184082
# 0.1685492992401123
# 0.17154860496520996
# 3.378934383392334
# 0.17752552032470703
# 0.16219544410705566
# 0.14576435089111328
# 0.1466045379638672
# 0.15161466598510742
# 0.1549837589263916
# 0.1515953540802002
# 0.15957427024841309
# 0.14560914039611816
# 0.13625645637512207
# 0.15259170532226562
# 0.15870428085327148
# 0.1476283073425293
# [[  label_color   sample point number  \
#   0         Neg  4836472          407
#   1         Neg  4836472          408
#   2         Neg  4836472          409
#   3         Neg  4836472          410
#   4         Pos  4836472          411
#   5         Neg  4836472          412
#   6         Neg  4836472          413
#   7         Neg  4836472          414
#   8         Neg  4836472          415
#   9         Neg  4836472          416
#
#                                    file_number unipolar    bipolar         x  \
#   0  2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt    20A_1    20A_1-2   1.83166
#   1  2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt    20A_3    20A_3-4  -5.13522
#   2  2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt    20A_5    20A_5-6  0.930086
#   3  2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt    20A_7    20A_7-8  -5.58346
#   4  2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt    20A_9   20A_9-10  -15.3675
#   5  2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt   20A_11  20A_11-12  -12.1253
#   6  2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt   20A_14  20A_13-14  -20.7784
#   7  2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt   20A_15  20A_15-16  -15.3298
#   8  2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt   20A_18  20A_17-18  -5.12803
#   9  2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt   20A_19  20A_19-20  -7.93404
#
#               y        z  refference_chanel
#   0     1.95644  88.6631  MCC_Abl_BiPolar_1
#   1    -1.49466  86.8315  MCC_Abl_BiPolar_1
#   2    -10.6205  81.1443  MCC_Abl_BiPolar_1
#   3    -6.54973  83.2922  MCC_Abl_BiPolar_1
#   4    -12.8436  77.0439  MCC_Abl_BiPolar_1
#   5    -7.06354  81.2519  MCC_Abl_BiPolar_1
#   6    -6.79787  84.6306  MCC_Abl_BiPolar_1
#   7    -4.67687  84.4275  MCC_Abl_BiPolar_1
#   8     3.23066  92.8192  MCC_Abl_BiPolar_1
#   9  -0.0944272  88.7103  MCC_Abl_BiPolar_1  ,
#   'F:/New folder\\2-1-SR_PsAF_3Extra_ECG_Export_4834472.txt',
#                M1     M2     M3     M4     V1     V2     V3     V4     V5  \
#   0.000000  0.054  0.210  0.051  0.030  0.045  0.057  0.093  0.060  0.057
#   0.001000  0.066  0.225  0.060  0.036  0.045  0.057  0.093  0.060  0.057
#   0.002001  0.075  0.237  0.066  0.042  0.042  0.060  0.093  0.063  0.060
#   0.003001  0.084  0.246  0.075  0.048  0.045  0.063  0.096  0.063  0.060
#   0.004002  0.090  0.258  0.090  0.060  0.045  0.069  0.096  0.066  0.063
#   ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
#   2.495998  0.018 -0.021  0.078  0.051 -0.165 -0.183 -0.180 -0.024  0.030
#   2.496999  0.015 -0.021  0.081  0.054 -0.159 -0.177 -0.174 -0.021  0.030
#   2.497999  0.009 -0.024  0.075  0.051 -0.156 -0.171 -0.171 -0.018  0.030
#   2.499000  0.009 -0.024  0.066  0.045 -0.150 -0.165 -0.165 -0.015  0.030
#   2.500000  0.012 -0.021  0.066  0.042 -0.147 -0.156 -0.159 -0.012  0.033
#
#                V6  ...  20A_18-19  20A_19-20    aVL    aVR    aVF  \
#   0.000000  0.048  ...      0.003     -0.006  0.042 -0.015 -0.030
#   0.001000  0.051  ...      0.003      0.000  0.042 -0.015 -0.027
#   0.002001  0.051  ...     -0.003      0.003  0.042 -0.015 -0.027
#   0.003001  0.051  ...      0.000      0.003  0.042 -0.015 -0.024
#   0.004002  0.051  ...      0.003      0.000  0.039 -0.018 -0.024
#   ...         ...  ...        ...        ...    ...    ...    ...
#   2.495998  0.042  ...      0.000      0.000  0.042 -0.084  0.042
#   2.496999  0.042  ...     -0.003      0.000  0.045 -0.084  0.039
#   2.497999  0.042  ...      0.000      0.000  0.045 -0.081  0.036
#   2.499000  0.039  ...     -0.006      0.003  0.045 -0.081  0.036
#   2.500000  0.039  ...      0.000      0.003  0.045 -0.078  0.033
#
#             MCC_Abl_BiPolar_1  MCC_Abl_BiPolar_2  MCC_Abl_BiPolar_3  \
#   0.000000              0.003              0.003              0.012
#   0.001000              0.003              0.006              0.012
#   0.002001              0.003              0.006              0.003
#   0.003001              0.006              0.006              0.000
#   0.004002              0.003              0.009              0.000
#   ...                     ...                ...                ...
#   2.495998              0.000              0.000             -0.009
#   2.496999             -0.003             -0.003             -0.009
#   2.497999              0.000             -0.009             -0.009
#   2.499000              0.003              0.000              0.003
#   2.500000              0.000             -0.003             -0.012
#
#             MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
#   0.000000             -0.015              0.003
#   0.001000             -0.006             -0.003
#   0.002001             -0.009              0.009
#   0.003001             -0.009              0.009
#   0.004002             -0.003              0.003
#   ...                     ...                ...
#   2.495998              0.003              0.006
#   2.496999              0.003              0.006
#   2.497999              0.006              0.003
#   2.499000              0.003             -0.006
#   2.500000              0.009              0.006
#
#   [2500 rows x 59 columns]],
#  [  label_color   sample point number  \
#   0         Neg  4881543          885
#   1         Neg  4881543          886
#   2         Neg  4881543          887
#   3         Neg  4881543          888
#   4         Neg  4881543          889
#   5         Neg  4881543          890
#   6         Pos  4881543          891
#   7         Pos  4881543          892
#   8         Pos  4881543          893
#   9         Pos  4881543          894
#
#                                    file_number unipolar    bipolar         x  \
#   0  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt    20A_2    20A_1-2  -13.1371
#   1  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt    20A_3    20A_3-4  -17.9368
#   2  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt    20A_5    20A_5-6  -10.4747
#   3  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt    20A_7    20A_7-8  -17.4159
#   4  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt   20A_10   20A_9-10  -24.1159
#   5  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt   20A_12  20A_11-12  -22.9175
#   6  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt   20A_14  20A_13-14  -33.4287
#   7  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt   20A_15  20A_15-16  -27.6849
#   8  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt   20A_17  20A_17-18  -24.9949
#   9  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt   20A_20  20A_19-20  -23.4032
#
#             y        z  refference_chanel
#   0  -18.0803  77.5021  MCC_Abl_BiPolar_1
#   1  -21.5291  76.5117  MCC_Abl_BiPolar_1
#   2  -31.4276  76.0026  MCC_Abl_BiPolar_1
#   3  -27.4644  76.1823  MCC_Abl_BiPolar_1
#   4  -36.3351  76.0792  MCC_Abl_BiPolar_1
#   5  -28.5506  76.2769  MCC_Abl_BiPolar_1
#   6  -27.0908  73.3042  MCC_Abl_BiPolar_1
#   7  -25.9844   74.605  MCC_Abl_BiPolar_1
#   8  -12.6322  80.2767  MCC_Abl_BiPolar_1
#   9  -21.4197  76.6981  MCC_Abl_BiPolar_1  ,
#   'F:/New folder\\2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt',
#                M1     M2     M3     M4     V1     V2     V3     V4     V5  \
#   0.000000  0.066  0.234  0.084  0.060 -0.039  0.015  0.087  0.069  0.072
#   0.001000  0.075  0.246  0.081  0.057 -0.042  0.018  0.090  0.069  0.075
#   0.002001  0.081  0.252  0.096  0.066 -0.042  0.021  0.090  0.072  0.075
#   0.003001  0.087  0.261  0.105  0.075 -0.042  0.024  0.093  0.072  0.078
#   0.004002  0.096  0.273  0.102  0.072 -0.042  0.027  0.093  0.075  0.081
#   ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
#   2.495998  0.012 -0.021  0.096  0.069 -0.135 -0.030 -0.069  0.042  0.111
#   2.496999  0.012 -0.018  0.099  0.069 -0.129 -0.027 -0.069  0.045  0.114
#   2.497999  0.012 -0.018  0.093  0.063 -0.123 -0.024 -0.066  0.048  0.114
#   2.499000  0.009 -0.021  0.087  0.057 -0.114 -0.021 -0.066  0.051  0.117
#   2.500000  0.006 -0.021  0.090  0.063 -0.108 -0.018 -0.069  0.051  0.117
#
#                V6  ...  20A_18-19  20A_19-20    aVL    aVR    aVF  \
#   0.000000  0.057  ...      0.000      0.000 -0.060 -0.057  0.117
#   0.001000  0.057  ...      0.000      0.000 -0.060 -0.060  0.120
#   0.002001  0.057  ...      0.000     -0.003 -0.063 -0.060  0.123
#   0.003001  0.057  ...     -0.003      0.000 -0.063 -0.060  0.123
#   0.004002  0.057  ...      0.000     -0.003 -0.063 -0.060  0.123
#   ...         ...  ...        ...        ...    ...    ...    ...
#   2.495998  0.102  ...      0.000      0.003  0.015 -0.072  0.060
#   2.496999  0.102  ...     -0.006      0.003  0.015 -0.075  0.060
#   2.497999  0.102  ...      0.003      0.000  0.015 -0.075  0.060
#   2.499000  0.102  ...     -0.003      0.003  0.018 -0.075  0.057
#   2.500000  0.102  ...     -0.003      0.003  0.018 -0.075  0.054
#
#             MCC_Abl_BiPolar_1  MCC_Abl_BiPolar_2  MCC_Abl_BiPolar_3  \
#   0.000000              0.000              0.003             -0.006
#   0.001000              0.000              0.012              0.000
#   0.002001              0.000              0.009              0.000
#   0.003001             -0.003              0.006             -0.006
#   0.004002              0.003              0.009              0.000
#   ...                     ...                ...                ...
#   2.495998              0.000             -0.003             -0.006
#   2.496999             -0.003              0.003              0.000
#   2.497999              0.003             -0.003              0.003
#   2.499000             -0.003             -0.003              0.000
#   2.500000              0.000             -0.003              0.000
#
#             MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
#   0.000000             -0.003              0.006
#   0.001000              0.006             -0.009
#   0.002001              0.003              0.000
#   0.003001              0.006              0.000
#   0.004002             -0.009              0.009
#   ...                     ...                ...
#   2.495998              0.006             -0.003
#   2.496999             -0.003              0.003
#   2.497999              0.000             -0.006
#   2.499000             -0.003              0.003
#   2.500000             -0.006              0.006
#
#   [2500 rows x 59 columns]],
#  [  label_color   sample point number  \
#   0         Neg  4938821         1387
#   1         Neg  4938821         1388
#   2         Neg  4938821         1389
#   3         Neg  4938821         1390
#   4         Neg  4938821         1391
#   5         Neg  4938821         1392
#   6         Neg  4938821         1393
#   7         Pos  4938821         1394
#   8         Neg  4938821         1395
#   9         Neg  4938821         1396
#
#                                    file_number unipolar    bipolar          x  \
#   0  2-1-SR_PsAF_3Extra_ECG_Export_4936821.txt    20A_1    20A_1-2   -1.11732
#   1  2-1-SR_PsAF_3Extra_ECG_Export_4936821.txt    20A_4    20A_3-4   -9.04426
#   2  2-1-SR_PsAF_3Extra_ECG_Export_4936821.txt    20A_5    20A_5-6  -0.861795
#   3  2-1-SR_PsAF_3Extra_ECG_Export_4936821.txt    20A_8    20A_7-8   -8.91182
#   4  2-1-SR_PsAF_3Extra_ECG_Export_4936821.txt   20A_10   20A_9-10   -13.2148
#   5  2-1-SR_PsAF_3Extra_ECG_Export_4936821.txt   20A_11  20A_11-12   -12.4978
#   6  2-1-SR_PsAF_3Extra_ECG_Export_4936821.txt   20A_14  20A_13-14    -22.882
#   7  2-1-SR_PsAF_3Extra_ECG_Export_4936821.txt   20A_16  20A_15-16   -15.4732
#   8  2-1-SR_PsAF_3Extra_ECG_Export_4936821.txt   20A_18  20A_17-18   -13.4114
#   9  2-1-SR_PsAF_3Extra_ECG_Export_4936821.txt   20A_20  20A_19-20   -12.5532
#
#             y        z  refference_chanel
#   0  -29.8731  77.2471  MCC_Abl_BiPolar_1
#   1  -35.6639  76.3649  MCC_Abl_BiPolar_1
#   2  -44.3094  80.6737  MCC_Abl_BiPolar_1
#   3  -39.5633  77.4535  MCC_Abl_BiPolar_1
#   4  -49.3692  77.9693  MCC_Abl_BiPolar_1
#   5  -43.5213  76.8624  MCC_Abl_BiPolar_1
#   6  -41.2794  74.7961  MCC_Abl_BiPolar_1
#   7  -39.1002  75.3477  MCC_Abl_BiPolar_1
#   8  -26.8019  74.7489  MCC_Abl_BiPolar_1
#   9  -34.4443  75.1995  MCC_Abl_BiPolar_1  ,
#   'F:/New folder\\2-1-SR_PsAF_3Extra_ECG_Export_4936821.txt',
#                M1     M2     M3     M4     V1     V2     V3     V4     V5  \
#   0.000000  0.045  0.168  0.042  0.024 -0.117 -0.060 -0.006 -0.075 -0.114
#   0.001000  0.057  0.177  0.057  0.036 -0.117 -0.060 -0.003 -0.072 -0.114
#   0.002001  0.063  0.186  0.063  0.048 -0.120 -0.060  0.000 -0.072 -0.117
#   0.003001  0.072  0.195  0.069  0.057 -0.120 -0.063  0.000 -0.069 -0.117
#   0.004002  0.081  0.204  0.075  0.063 -0.123 -0.066  0.000 -0.069 -0.117
#   ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
#   2.495998  0.015 -0.015  0.168  0.135 -0.315 -0.381 -0.252 -0.144 -0.060
#   2.496999  0.015 -0.015  0.171  0.141 -0.309 -0.375 -0.252 -0.144 -0.060
#   2.497999  0.015 -0.015  0.174  0.144 -0.306 -0.372 -0.249 -0.141 -0.060
#   2.499000  0.012 -0.018  0.168  0.141 -0.303 -0.369 -0.249 -0.141 -0.060
#   2.500000  0.012 -0.015  0.177  0.147 -0.300 -0.366 -0.249 -0.138 -0.057
#
#                V6  ...  20A_18-19  20A_19-20    aVL    aVR    aVF  \
#   0.000000 -0.159  ...      0.000      0.003 -0.081  0.000  0.081
#   0.001000 -0.159  ...      0.000      0.000 -0.081  0.000  0.081
#   0.002001 -0.159  ...      0.000      0.003 -0.081 -0.003  0.084
#   0.003001 -0.159  ...      0.003     -0.003 -0.084 -0.003  0.087
#   0.004002 -0.159  ...     -0.003      0.003 -0.084 -0.006  0.090
#   ...         ...  ...        ...        ...    ...    ...    ...
#   2.495998 -0.033  ...      0.003      0.006 -0.141 -0.147  0.288
#   2.496999 -0.033  ...      0.003      0.006 -0.141 -0.144  0.285
#   2.497999 -0.033  ...      0.009      0.003 -0.141 -0.144  0.285
#   2.499000 -0.033  ...      0.000      0.006 -0.141 -0.144  0.285
#   2.500000 -0.036  ...      0.003      0.006 -0.138 -0.144  0.282
#
#             MCC_Abl_BiPolar_1  MCC_Abl_BiPolar_2  MCC_Abl_BiPolar_3  \
#   0.000000              0.006              0.006             -0.003
#   0.001000              0.000              0.003              0.000
#   0.002001              0.003              0.003             -0.015
#   0.003001              0.000              0.000              0.006
#   0.004002              0.003              0.003             -0.006
#   ...                     ...                ...                ...
#   2.495998              0.000              0.003              0.003
#   2.496999              0.000             -0.003             -0.006
#   2.497999              0.000              0.000              0.000
#   2.499000              0.000              0.000             -0.003
#   2.500000             -0.003              0.000              0.003
#
#             MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
#   0.000000              0.003              0.000
#   0.001000              0.006             -0.003
#   0.002001              0.003              0.012
#   0.003001             -0.003             -0.003
#   0.004002              0.015             -0.009
#   ...                     ...                ...
#   2.495998             -0.003             -0.003
#   2.496999              0.000              0.006
#   2.497999             -0.009              0.006
#   2.499000              0.000              0.003
#   2.500000             -0.006              0.003
#
#   [2500 rows x 59 columns]],
#  [  label_color   sample point number  \
#   0         Neg  5023052         2044
#   1         Neg  5023052         2045
#   2         Pos  5023052         2046
#   3         Pos  5023052         2047
#   4         Neg  5023052         2048
#   5         Neg  5023052         2049
#   6         Neg  5023052         2050
#   7         Neg  5023052         2051
#   8         Neg  5023052         2052
#   9         Neg  5023052         2053
#
#                                    file_number unipolar    bipolar         x  \
#   0  2-1-SR_PsAF_3Extra_ECG_Export_5021052.txt    20A_1    20A_1-2   14.9521
#   1  2-1-SR_PsAF_3Extra_ECG_Export_5021052.txt    20A_3    20A_3-4   7.69063
#   2  2-1-SR_PsAF_3Extra_ECG_Export_5021052.txt    20A_6    20A_5-6   5.51704
#   3  2-1-SR_PsAF_3Extra_ECG_Export_5021052.txt    20A_7    20A_7-8   4.26666
#   4  2-1-SR_PsAF_3Extra_ECG_Export_5021052.txt    20A_9   20A_9-10  -2.06307
#   5  2-1-SR_PsAF_3Extra_ECG_Export_5021052.txt   20A_11  20A_11-12  0.692297
#   6  2-1-SR_PsAF_3Extra_ECG_Export_5021052.txt   20A_13  20A_13-14  -8.74832
#   7  2-1-SR_PsAF_3Extra_ECG_Export_5021052.txt   20A_15  20A_15-16  -2.01558
#   8  2-1-SR_PsAF_3Extra_ECG_Export_5021052.txt   20A_17  20A_17-18  -7.98789
#   9  2-1-SR_PsAF_3Extra_ECG_Export_5021052.txt   20A_19  20A_19-20  -1.42076
#
#             y        z  refference_chanel
#   0  -20.9385  82.5339  MCC_Abl_BiPolar_1
#   1  -23.8862  80.9504  MCC_Abl_BiPolar_1
#   2  -32.7686  89.0873  MCC_Abl_BiPolar_1
#   3  -29.2424  84.4162  MCC_Abl_BiPolar_1
#   4  -38.3639  83.4674  MCC_Abl_BiPolar_1
#   5  -31.0931  81.6101  MCC_Abl_BiPolar_1
#   6  -30.9745  74.6412  MCC_Abl_BiPolar_1
#   7   -28.211  77.9237  MCC_Abl_BiPolar_1
#   8  -18.9243  77.0778  MCC_Abl_BiPolar_1
#   9  -23.1779  78.2404  MCC_Abl_BiPolar_1  ,
#   'F:/New folder\\2-1-SR_PsAF_3Extra_ECG_Export_5021052.txt',
#                M1     M2     M3     M4     V1     V2     V3     V4     V5  \
#   0.000000  0.081  0.234  0.096  0.072 -0.024  0.048  0.093  0.054  0.057
#   0.001000  0.087  0.240  0.105  0.078 -0.021  0.048  0.093  0.057  0.057
#   0.002001  0.096  0.246  0.105  0.078 -0.021  0.051  0.093  0.057  0.057
#   0.003001  0.105  0.255  0.117  0.084 -0.018  0.051  0.093  0.060  0.057
#   0.004002  0.111  0.258  0.117  0.084 -0.018  0.054  0.093  0.060  0.060
#   ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
#   2.495998  0.021 -0.015  0.078  0.051 -0.126 -0.249 -0.144  0.009  0.012
#   2.496999  0.021 -0.015  0.084  0.057 -0.126 -0.252 -0.144  0.012  0.015
#   2.497999  0.021 -0.015  0.084  0.054 -0.126 -0.252 -0.144  0.012  0.015
#   2.499000  0.021 -0.015  0.087  0.057 -0.126 -0.255 -0.144  0.012  0.015
#   2.500000  0.018 -0.015  0.093  0.063 -0.126 -0.255 -0.144  0.012  0.018
#
#                V6  ...  20A_18-19  20A_19-20    aVL    aVR    aVF  \
#   0.000000  0.051  ...      0.003      0.000 -0.033 -0.078  0.108
#   0.001000  0.051  ...      0.003      0.000 -0.033 -0.078  0.111
#   0.002001  0.051  ...      0.003      0.003 -0.036 -0.078  0.114
#   0.003001  0.051  ...      0.003      0.003 -0.039 -0.078  0.117
#   0.004002  0.048  ...      0.003      0.000 -0.039 -0.078  0.117
#   ...         ...  ...        ...        ...    ...    ...    ...
#   2.495998  0.042  ...      0.000      0.003 -0.060 -0.096  0.153
#   2.496999  0.042  ...      0.006     -0.006 -0.060 -0.099  0.156
#   2.497999  0.042  ...      0.006      0.000 -0.060 -0.099  0.159
#   2.499000  0.042  ...      0.000      0.000 -0.060 -0.102  0.162
#   2.500000  0.045  ...      0.003      0.003 -0.063 -0.105  0.165
#
#             MCC_Abl_BiPolar_1  MCC_Abl_BiPolar_2  MCC_Abl_BiPolar_3  \
#   0.000000              0.003              0.006             -0.006
#   0.001000              0.003              0.006              0.000
#   0.002001              0.003              0.009             -0.003
#   0.003001              0.003              0.006             -0.009
#   0.004002              0.000              0.006              0.000
#   ...                     ...                ...                ...
#   2.495998              0.003              0.000              0.003
#   2.496999              0.003              0.000             -0.006
#   2.497999              0.000              0.003              0.000
#   2.499000              0.000              0.000             -0.003
#   2.500000              0.000              0.003              0.000
#
#             MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
#   0.000000              0.003              0.006
#   0.001000              0.000              0.000
#   0.002001              0.006             -0.003
#   0.003001              0.000              0.006
#   0.004002              0.003             -0.003
#   ...                     ...                ...
#   2.495998              0.003             -0.006
#   2.496999              0.006              0.003
#   2.497999             -0.003              0.003
#   2.499000              0.006              0.000
#   2.500000             -0.003              0.003
#
#   [2500 rows x 59 columns]],
#  [  label_color   sample point number  \
#   0         Pos  5045060         2227
#   1         Pos  5045060         2228
#   2         Neg  5045060         2229
#   3         Neg  5045060         2230
#   4         Neg  5045060         2231
#   5         Neg  5045060         2232
#   6         Neg  5045060         2233
#   7         Neg  5045060         2234
#   8         Neg  5045060         2235
#   9         Neg  5045060         2236
#
#                                    file_number unipolar    bipolar         x  \
#   0  2-1-SR_PsAF_3Extra_ECG_Export_5043060.txt    20A_1    20A_1-2  -35.8165
#   1  2-1-SR_PsAF_3Extra_ECG_Export_5043060.txt    20A_3    20A_3-4  -36.7162
#   2  2-1-SR_PsAF_3Extra_ECG_Export_5043060.txt    20A_6    20A_5-6  -26.4365
#   3  2-1-SR_PsAF_3Extra_ECG_Export_5043060.txt    20A_7    20A_7-8  -32.1633
#   4  2-1-SR_PsAF_3Extra_ECG_Export_5043060.txt    20A_9   20A_9-10  -32.5915
#   5  2-1-SR_PsAF_3Extra_ECG_Export_5043060.txt   20A_12  20A_11-12  -36.1161
#   6  2-1-SR_PsAF_3Extra_ECG_Export_5043060.txt   20A_13  20A_13-14  -46.3246
#   7  2-1-SR_PsAF_3Extra_ECG_Export_5043060.txt   20A_16  20A_15-16  -40.0367
#   8  2-1-SR_PsAF_3Extra_ECG_Export_5043060.txt   20A_18  20A_17-18  -45.4597
#   9  2-1-SR_PsAF_3Extra_ECG_Export_5043060.txt   20A_19  20A_19-20   -41.439
#
#             y        z  refference_chanel
#   0  -43.0041  72.5055  MCC_Abl_BiPolar_1
#   1  -49.2955  77.2303  MCC_Abl_BiPolar_1
#   2  -55.4898  83.3025  MCC_Abl_BiPolar_1
#   3   -54.198  82.0964  MCC_Abl_BiPolar_1
#   4  -57.8362  92.9858  MCC_Abl_BiPolar_1
#   5  -54.1252  84.5807  MCC_Abl_BiPolar_1
#   6  -52.1803  91.5505  MCC_Abl_BiPolar_1
#   7  -52.8368  84.1409  MCC_Abl_BiPolar_1
#   8  -46.7432  75.5588  MCC_Abl_BiPolar_1
#   9  -50.0785  78.5071  MCC_Abl_BiPolar_1  ,
#   'F:/New folder\\2-1-SR_PsAF_3Extra_ECG_Export_5043060.txt',
#                M1     M2     M3     M4     V1     V2     V3     V4     V5  \
#   0.000000  0.000  0.231  0.054  0.036 -0.081 -0.057  0.009 -0.027  0.015
#   0.001000  0.006  0.240  0.063  0.045 -0.081 -0.060  0.009 -0.024  0.018
#   0.002001  0.018  0.252  0.072  0.054 -0.081 -0.063  0.009 -0.024  0.021
#   0.003001  0.030  0.261  0.084  0.063 -0.081 -0.066  0.009 -0.021  0.024
#   0.004002  0.039  0.270  0.087  0.066 -0.084 -0.066  0.009 -0.018  0.024
#   ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
#   2.495998  0.018 -0.015  0.105  0.069 -0.198 -0.195 -0.177 -0.039  0.018
#   2.496999  0.018 -0.012  0.114  0.078 -0.195 -0.198 -0.177 -0.036  0.024
#   2.497999  0.021 -0.009  0.102  0.069 -0.192 -0.198 -0.177 -0.036  0.027
#   2.499000  0.018 -0.009  0.108  0.072 -0.189 -0.201 -0.180 -0.033  0.030
#   2.500000  0.012 -0.015  0.114  0.075 -0.186 -0.201 -0.180 -0.033  0.033
#
#                V6  ...  20A_18-19  20A_19-20    aVL    aVR    aVF  \
#   0.000000  0.021  ...      0.000      0.003 -0.021 -0.072  0.093
#   0.001000  0.021  ...      0.003      0.000 -0.021 -0.072  0.096
#   0.002001  0.021  ...      0.000     -0.003 -0.021 -0.075  0.096
#   0.003001  0.021  ...     -0.003      0.006 -0.021 -0.075  0.099
#   0.004002  0.021  ...      0.000      0.000 -0.021 -0.078  0.099
#   ...         ...  ...        ...        ...    ...    ...    ...
#   2.495998  0.042  ...     -0.003      0.000 -0.036 -0.030  0.066
#   2.496999  0.045  ...      0.003      0.000 -0.036 -0.033  0.069
#   2.497999  0.045  ...      0.000      0.003 -0.036 -0.033  0.072
#   2.499000  0.048  ...      0.003      0.000 -0.039 -0.036  0.075
#   2.500000  0.048  ...      0.000      0.000 -0.039 -0.036  0.075
#
#             MCC_Abl_BiPolar_1  MCC_Abl_BiPolar_2  MCC_Abl_BiPolar_3  \
#   0.000000              0.000              0.003              0.000
#   0.001000              0.000              0.009             -0.009
#   0.002001              0.006              0.003              0.000
#   0.003001              0.000              0.006             -0.006
#   0.004002              0.003              0.006             -0.003
#   ...                     ...                ...                ...
#   2.495998              0.000              0.000             -0.003
#   2.496999              0.000              0.000             -0.003
#   2.497999              0.000              0.003              0.000
#   2.499000              0.000              0.003              0.000
#   2.500000              0.000              0.000             -0.009
#
#             MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
#   0.000000              0.009             -0.009
#   0.001000              0.000              0.006
#   0.002001             -0.003              0.003
#   0.003001              0.003              0.003
#   0.004002              0.000              0.003
#   ...                     ...                ...
#   2.495998              0.003              0.000
#   2.496999              0.003             -0.003
#   2.497999              0.000              0.000
#   2.499000              0.006             -0.006
#   2.500000              0.009              0.000
#
#   [2500 rows x 59 columns]],
#  [  label_color   sample point number  \
#   0         Neg  5076211         2488
#   1         Neg  5076211         2489
#   2         Neg  5076211         2490
#   3         Neg  5076211         2491
#   4         Neg  5076211         2492
#   5         Neg  5076211         2493
#   6         Neg  5076211         2494
#   7         Neg  5076211         2495
#   8         Neg  5076211         2496
#   9         Neg  5076211         2497
#
#                                    file_number unipolar    bipolar         x  \
#   0  2-1-SR_PsAF_3Extra_ECG_Export_5074211.txt    20A_1    20A_1-2  -5.65497
#   1  2-1-SR_PsAF_3Extra_ECG_Export_5074211.txt    20A_4    20A_3-4  -14.3308
#   2  2-1-SR_PsAF_3Extra_ECG_Export_5074211.txt    20A_6    20A_5-6  -7.81684
#   3  2-1-SR_PsAF_3Extra_ECG_Export_5074211.txt    20A_8    20A_7-8  -14.4577
#   4  2-1-SR_PsAF_3Extra_ECG_Export_5074211.txt    20A_9   20A_9-10  -13.9327
#   5  2-1-SR_PsAF_3Extra_ECG_Export_5074211.txt   20A_11  20A_11-12  -16.3705
#   6  2-1-SR_PsAF_3Extra_ECG_Export_5074211.txt   20A_13  20A_13-14  -30.1593
#   7  2-1-SR_PsAF_3Extra_ECG_Export_5074211.txt   20A_15  20A_15-16  -22.7439
#   8  2-1-SR_PsAF_3Extra_ECG_Export_5074211.txt   20A_18  20A_17-18  -19.4418
#   9  2-1-SR_PsAF_3Extra_ECG_Export_5074211.txt   20A_19  20A_19-20  -18.3358
#
#             y        z  refference_chanel
#   0  -54.6109  82.1741  MCC_Abl_BiPolar_1
#   1  -58.1752  85.1875  MCC_Abl_BiPolar_1
#   2  -61.3287  92.6876  MCC_Abl_BiPolar_1
#   3  -59.8708  88.6369  MCC_Abl_BiPolar_1
#   4  -64.3116  98.6827  MCC_Abl_BiPolar_1
#   5  -61.8891  91.5202  MCC_Abl_BiPolar_1
#   6  -57.7413  89.8396  MCC_Abl_BiPolar_1
#   7  -59.5815  87.7462  MCC_Abl_BiPolar_1
#   8  -52.2228   78.314  MCC_Abl_BiPolar_1
#   9  -56.5321   82.227  MCC_Abl_BiPolar_1  ,
#   'F:/New folder\\2-1-SR_PsAF_3Extra_ECG_Export_5074211.txt',
#                M1     M2     M3     M4     V1     V2     V3     V4     V5  \
#   0.000000  0.096 -0.078  0.027  0.063  0.021  0.024  0.009  0.012  0.024
#   0.001000  0.099 -0.075  0.030  0.069  0.021  0.021  0.009  0.015  0.024
#   0.002001  0.099 -0.072  0.030  0.069  0.021  0.021  0.012  0.015  0.024
#   0.003001  0.102 -0.066  0.027  0.066  0.018  0.021  0.012  0.018  0.024
#   0.004002  0.102 -0.063  0.024  0.063  0.018  0.018  0.012  0.018  0.021
#   ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
#   2.495998  0.021 -0.018  0.027  0.021  0.009  0.000 -0.012 -0.018 -0.024
#   2.496999  0.021 -0.018  0.030  0.024  0.006 -0.003 -0.012 -0.018 -0.021
#   2.497999  0.018 -0.018  0.027  0.018  0.006 -0.006 -0.012 -0.018 -0.018
#   2.499000  0.018 -0.018  0.024  0.018  0.006 -0.012 -0.012 -0.018 -0.015
#   2.500000  0.018 -0.018  0.033  0.027  0.006 -0.015 -0.012 -0.018 -0.012
#
#                V6  ...  20A_18-19  20A_19-20    aVL    aVR    aVF  \
#   0.000000  0.021  ...     -0.015      0.003  0.030  0.039 -0.069
#   0.001000  0.021  ...     -0.012      0.006  0.030  0.039 -0.066
#   0.002001  0.021  ...     -0.015      0.000  0.030  0.036 -0.066
#   0.003001  0.024  ...     -0.009      0.000  0.030  0.039 -0.066
#   0.004002  0.021  ...     -0.012      0.000  0.027  0.039 -0.066
#   ...         ...  ...        ...        ...    ...    ...    ...
#   2.495998 -0.033  ...      0.000      0.000  0.027 -0.012 -0.015
#   2.496999 -0.030  ...      0.000     -0.003  0.027 -0.012 -0.015
#   2.497999 -0.030  ...      0.000     -0.003  0.027 -0.012 -0.015
#   2.499000 -0.030  ...     -0.006      0.000  0.027 -0.012 -0.015
#   2.500000 -0.030  ...      0.000      0.000  0.027 -0.012 -0.015
#
#             MCC_Abl_BiPolar_1  MCC_Abl_BiPolar_2  MCC_Abl_BiPolar_3  \
#   0.000000             -0.012              0.000              0.003
#   0.001000             -0.009              0.000              0.000
#   0.002001             -0.009              0.000             -0.006
#   0.003001             -0.012              0.003              0.003
#   0.004002             -0.006              0.000             -0.003
#   ...                     ...                ...                ...
#   2.495998              0.000              0.003              0.000
#   2.496999              0.003              0.003             -0.003
#   2.497999             -0.003             -0.003              0.000
#   2.499000              0.003              0.000             -0.006
#   2.500000              0.000             -0.003              0.003
#
#             MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
#   0.000000             -0.009              0.006
#   0.001000              0.006             -0.006
#   0.002001             -0.006              0.009
#   0.003001             -0.003              0.000
#   0.004002              0.006             -0.003
#   ...                     ...                ...
#   2.495998              0.003             -0.003
#   2.496999             -0.003              0.006
#   2.497999              0.000              0.000
#   2.499000              0.000              0.006
#   2.500000             -0.006              0.003
#
#   [2500 rows x 59 columns]],
#  [  label_color   sample point number  \
#   0         Neg  5129562         2871
#   1         Neg  5129562         2872
#   2         Neg  5129562         2873
#   3         Neg  5129562         2874
#   4         Neg  5129562         2875
#   5         Neg  5129562         2876
#   6         Neg  5129562         2877
#   7         Neg  5129562         2878
#   8         Neg  5129562         2879
#   9         Neg  5129562         2880
#
#                                    file_number unipolar    bipolar        x  \
#   0  2-1-SR_PsAF_3Extra_ECG_Export_5127562.txt    20A_1    20A_1-2  8.74471
#   1  2-1-SR_PsAF_3Extra_ECG_Export_5127562.txt    20A_3    20A_3-4  13.3729
#   2  2-1-SR_PsAF_3Extra_ECG_Export_5127562.txt    20A_5    20A_5-6  23.1103
#   3  2-1-SR_PsAF_3Extra_ECG_Export_5127562.txt    20A_7    20A_7-8   18.087
#   4  2-1-SR_PsAF_3Extra_ECG_Export_5127562.txt    20A_9   20A_9-10  15.9923
#   5  2-1-SR_PsAF_3Extra_ECG_Export_5127562.txt   20A_11  20A_11-12  15.7365
#   6  2-1-SR_PsAF_3Extra_ECG_Export_5127562.txt   20A_13  20A_13-14  14.5879
#   7  2-1-SR_PsAF_3Extra_ECG_Export_5127562.txt   20A_15  20A_15-16  15.2954
#   8  2-1-SR_PsAF_3Extra_ECG_Export_5127562.txt   20A_17  20A_17-18  14.3315
#   9  2-1-SR_PsAF_3Extra_ECG_Export_5127562.txt   20A_19  20A_19-20  14.7506
#
#             y        z  refference_chanel
#   0   -33.911  118.689  MCC_Abl_BiPolar_1
#   1  -33.2696  112.807  MCC_Abl_BiPolar_1
#   2  -43.8102  110.045  MCC_Abl_BiPolar_1
#   3  -37.7388   108.67  MCC_Abl_BiPolar_1
#   4  -43.2599  98.3294  MCC_Abl_BiPolar_1
#   5  -37.3454  103.628  MCC_Abl_BiPolar_1
#   6  -24.5901  97.2867  MCC_Abl_BiPolar_1
#   7  -29.7797  103.234  MCC_Abl_BiPolar_1
#   8  -19.7949   107.87  MCC_Abl_BiPolar_1
#   9   -27.771  107.853  MCC_Abl_BiPolar_1  ,
#   'F:/New folder\\2-1-SR_PsAF_3Extra_ECG_Export_5127562.txt',
#                M1     M2     M3     M4     V1     V2     V3     V4     V5  \
#   0.000000  0.126 -0.042  0.018  0.039 -0.108 -0.099 -0.174 -0.147 -0.102
#   0.001000  0.126 -0.042  0.024  0.045 -0.108 -0.099 -0.174 -0.147 -0.102
#   0.002001  0.123 -0.039  0.018  0.039 -0.108 -0.102 -0.174 -0.147 -0.102
#   0.003001  0.123 -0.039  0.012  0.033 -0.111 -0.102 -0.174 -0.147 -0.102
#   0.004002  0.120 -0.036  0.015  0.030 -0.111 -0.102 -0.174 -0.150 -0.105
#   ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
#   2.495998  0.015 -0.018  0.012  0.009 -0.063 -0.147 -0.126 -0.273 -0.153
#   2.496999  0.012 -0.021  0.012  0.009 -0.060 -0.144 -0.129 -0.273 -0.150
#   2.497999  0.009 -0.024  0.012  0.006 -0.054 -0.141 -0.129 -0.273 -0.150
#   2.499000  0.009 -0.024  0.012  0.009 -0.048 -0.138 -0.132 -0.273 -0.150
#   2.500000  0.012 -0.024  0.006  0.003 -0.042 -0.138 -0.132 -0.273 -0.147
#
#                V6  ...  20A_18-19  20A_19-20    aVL    aVR    aVF  \
#   0.000000 -0.060  ...      0.003      0.003  0.087  0.084 -0.174
#   0.001000 -0.057  ...      0.000      0.006  0.090  0.084 -0.174
#   0.002001 -0.054  ...      0.003      0.003  0.090  0.084 -0.174
#   0.003001 -0.054  ...      0.003      0.000  0.090  0.084 -0.174
#   0.004002 -0.054  ...      0.003      0.000  0.090  0.084 -0.171
#   ...         ...  ...        ...        ...    ...    ...    ...
#   2.495998 -0.099  ...     -0.006      0.003  0.003  0.021 -0.024
#   2.496999 -0.099  ...      0.000      0.000  0.003  0.021 -0.024
#   2.497999 -0.099  ...     -0.003      0.000  0.003  0.021 -0.024
#   2.499000 -0.099  ...      0.000     -0.003  0.006  0.021 -0.027
#   2.500000 -0.099  ...      0.006     -0.003  0.006  0.024 -0.030
#
#             MCC_Abl_BiPolar_1  MCC_Abl_BiPolar_2  MCC_Abl_BiPolar_3  \
#   0.000000              0.006              0.000              0.003
#   0.001000              0.003              0.000             -0.006
#   0.002001              0.000              0.000             -0.006
#   0.003001             -0.006              0.006              0.006
#   0.004002             -0.006              0.000             -0.006
#   ...                     ...                ...                ...
#   2.495998             -0.003             -0.003             -0.003
#   2.496999              0.000             -0.003              0.000
#   2.497999              0.000              0.000              0.000
#   2.499000              0.003             -0.003              0.000
#   2.500000              0.003             -0.003              0.003
#
#             MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
#   0.000000             -0.009              0.006
#   0.001000              0.003              0.003
#   0.002001             -0.006              0.012
#   0.003001             -0.009              0.003
#   0.004002              0.009              0.000
#   ...                     ...                ...
#   2.495998              0.000              0.006
#   2.496999              0.000              0.000
#   2.497999             -0.003              0.003
#   2.499000             -0.006              0.009
#   2.500000             -0.003             -0.003
#
#   [2500 rows x 59 columns]],
#  [  label_color   sample point number  \
#   0         Neg  5140633         2976
#   1         Neg  5140633         2977
#   2         Neg  5140633         2978
#   3         Neg  5140633         2979
#   4         Neg  5140633         2980
#   5         Neg  5140633         2981
#   6         Pos  5140633         2982
#   7         Neg  5140633         2983
#   8         Neg  5140633         2984
#   9         Neg  5140633         2985
#
#                                    file_number unipolar    bipolar        x  \
#   0  2-1-SR_PsAF_3Extra_ECG_Export_5138633.txt    20A_1    20A_1-2  20.9112
#   1  2-1-SR_PsAF_3Extra_ECG_Export_5138633.txt    20A_4    20A_3-4  14.3365
#   2  2-1-SR_PsAF_3Extra_ECG_Export_5138633.txt    20A_5    20A_5-6  15.1354
#   3  2-1-SR_PsAF_3Extra_ECG_Export_5138633.txt    20A_8    20A_7-8  12.8033
#   4  2-1-SR_PsAF_3Extra_ECG_Export_5138633.txt    20A_9   20A_9-10  1.91016
#   5  2-1-SR_PsAF_3Extra_ECG_Export_5138633.txt   20A_12  20A_11-12  9.58931
#   6  2-1-SR_PsAF_3Extra_ECG_Export_5138633.txt   20A_14  20A_13-14  6.99316
#   7  2-1-SR_PsAF_3Extra_ECG_Export_5138633.txt   20A_16  20A_15-16  10.7521
#   8  2-1-SR_PsAF_3Extra_ECG_Export_5138633.txt   20A_18  20A_17-18  15.3871
#   9  2-1-SR_PsAF_3Extra_ECG_Export_5138633.txt   20A_19  20A_19-20  14.0353
#
#             y        z  refference_chanel
#   0  -47.6602  104.963  MCC_Abl_BiPolar_1
#   1  -47.8905  97.5494  MCC_Abl_BiPolar_1
#   2  -58.6327  102.694  MCC_Abl_BiPolar_1
#   3  -51.1536  96.7056  MCC_Abl_BiPolar_1
#   4   -54.483  88.6914  MCC_Abl_BiPolar_1
#   5  -50.1549  92.7563  MCC_Abl_BiPolar_1
#   6  -40.0525  88.7149  MCC_Abl_BiPolar_1
#   7  -45.6844  92.3697  MCC_Abl_BiPolar_1
#   8  -37.3145   96.616  MCC_Abl_BiPolar_1
#   9  -42.9812  95.3681  MCC_Abl_BiPolar_1  ,
#   'F:/New folder\\2-1-SR_PsAF_3Extra_ECG_Export_5138633.txt',
#                M1     M2     M3     M4     V1     V2     V3     V4     V5  \
#   0.000000 -0.018  0.150 -0.045 -0.048  0.003  0.021  0.009  0.009  0.006
#   0.001000 -0.018  0.153 -0.045 -0.045  0.003  0.021  0.009  0.012  0.006
#   0.002001 -0.018  0.159 -0.036 -0.039  0.003  0.018  0.009  0.012  0.006
#   0.003001 -0.015  0.162 -0.033 -0.036  0.000  0.018  0.009  0.012  0.006
#   0.004002 -0.012  0.168 -0.030 -0.036 -0.003  0.015  0.012  0.012  0.006
#   ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
#   2.495998  0.015 -0.012  0.114  0.084  0.120  0.150  0.093  0.132  0.231
#   2.496999  0.015 -0.012  0.114  0.081  0.120  0.153  0.093  0.135  0.234
#   2.497999  0.015 -0.009  0.117  0.084  0.123  0.156  0.096  0.135  0.237
#   2.499000  0.018 -0.009  0.126  0.093  0.126  0.159  0.099  0.138  0.240
#   2.500000  0.012 -0.009  0.123  0.087  0.126  0.162  0.102  0.141  0.240
#
#                V6  ...  20A_18-19  20A_19-20    aVL    aVR    aVF  \
#   0.000000  0.021  ...      0.003      0.003  0.030  0.027 -0.057
#   0.001000  0.024  ...      0.006      0.003  0.030  0.027 -0.057
#   0.002001  0.024  ...      0.009      0.003  0.030  0.027 -0.057
#   0.003001  0.021  ...      0.003      0.006  0.030  0.027 -0.057
#   0.004002  0.021  ...      0.006      0.003  0.030  0.027 -0.057
#   ...         ...  ...        ...        ...    ...    ...    ...
#   2.495998  0.204  ...      0.006      0.003  0.198  0.021 -0.216
#   2.496999  0.207  ...      0.003      0.000  0.195  0.018 -0.216
#   2.497999  0.207  ...      0.003      0.000  0.192  0.018 -0.213
#   2.499000  0.207  ...      0.006      0.000  0.192  0.018 -0.210
#   2.500000  0.207  ...      0.003      0.006  0.189  0.018 -0.210
#
#             MCC_Abl_BiPolar_1  MCC_Abl_BiPolar_2  MCC_Abl_BiPolar_3  \
#   0.000000              0.000              0.003              0.006
#   0.001000              0.000              0.003              0.000
#   0.002001              0.003              0.003             -0.003
#   0.003001              0.000              0.000              0.000
#   0.004002              0.003              0.003              0.000
#   ...                     ...                ...                ...
#   2.495998              0.000              0.000              0.000
#   2.496999              0.000              0.000              0.000
#   2.497999              0.000              0.003              0.003
#   2.499000              0.000              0.003              0.003
#   2.500000             -0.003              0.000              0.003
#
#             MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
#   0.000000             -0.003             -0.003
#   0.001000              0.009             -0.006
#   0.002001              0.000              0.003
#   0.003001              0.000             -0.003
#   0.004002              0.006             -0.006
#   ...                     ...                ...
#   2.495998              0.000              0.000
#   2.496999              0.000             -0.003
#   2.497999              0.000             -0.003
#   2.499000             -0.006              0.003
#   2.500000              0.012             -0.015
#
#   [2500 rows x 59 columns]],
#  [  label_color   sample point number  \
#   0         Neg  5156977         3139
#   1         Neg  5156977         3140
#   2         Neg  5156977         3141
#   3         Neg  5156977         3142
#   4         Neg  5156977         3143
#   5         Neg  5156977         3144
#   6         Neg  5156977         3145
#   7         Neg  5156977         3146
#   8         Neg  5156977         3147
#   9         Neg  5156977         3148
#
#                                    file_number unipolar    bipolar         x  \
#   0  2-1-SR_PsAF_3Extra_ECG_Export_5154977.txt    20A_1    20A_1-2   12.8344
#   1  2-1-SR_PsAF_3Extra_ECG_Export_5154977.txt    20A_4    20A_3-4   7.34628
#   2  2-1-SR_PsAF_3Extra_ECG_Export_5154977.txt    20A_6    20A_5-6   4.60499
#   3  2-1-SR_PsAF_3Extra_ECG_Export_5154977.txt    20A_7    20A_7-8   5.29472
#   4  2-1-SR_PsAF_3Extra_ECG_Export_5154977.txt    20A_9   20A_9-10  -1.50288
#   5  2-1-SR_PsAF_3Extra_ECG_Export_5154977.txt   20A_12  20A_11-12   3.82004
#   6  2-1-SR_PsAF_3Extra_ECG_Export_5154977.txt   20A_14  20A_13-14   2.85002
#   7  2-1-SR_PsAF_3Extra_ECG_Export_5154977.txt   20A_16  20A_15-16   4.83182
#   8  2-1-SR_PsAF_3Extra_ECG_Export_5154977.txt   20A_17  20A_17-18   12.9081
#   9  2-1-SR_PsAF_3Extra_ECG_Export_5154977.txt   20A_19  20A_19-20   8.37515
#
#             y        z  refference_chanel
#   0  -56.7985  105.533  MCC_Abl_BiPolar_1
#   1  -57.4114  97.3116  MCC_Abl_BiPolar_1
#   2  -65.8526  102.451  MCC_Abl_BiPolar_1
#   3    -61.82  98.0949  MCC_Abl_BiPolar_1
#   4  -67.5504   98.875  MCC_Abl_BiPolar_1
#   5  -60.9322  94.7085  MCC_Abl_BiPolar_1
#   6  -50.0625  86.3274  MCC_Abl_BiPolar_1
#   7  -55.6016  91.2999  MCC_Abl_BiPolar_1
#   8   -46.649  95.8124  MCC_Abl_BiPolar_1
#   9  -53.0458  94.5097  MCC_Abl_BiPolar_1  ,
#   'F:/New folder\\2-1-SR_PsAF_3Extra_ECG_Export_5154977.txt',
#                M1     M2     M3     M4     V1     V2     V3     V4     V5  \
#   0.000000  0.129 -0.189  0.078  0.117 -0.003  0.006  0.000  0.000 -0.003
#   0.001000  0.126 -0.192  0.072  0.111 -0.006  0.009  0.003  0.000 -0.003
#   0.002001  0.126 -0.198  0.072  0.111 -0.009  0.009  0.003  0.000 -0.006
#   0.003001  0.123 -0.204  0.069  0.105 -0.009  0.009  0.006  0.003 -0.006
#   0.004002  0.120 -0.207  0.069  0.105 -0.009  0.009  0.006  0.003 -0.006
#   ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
#   2.495998 -0.027 -0.063  0.558  0.528  0.252  0.450  0.117  0.039  0.159
#   2.496999 -0.027 -0.060  0.564  0.537  0.252  0.450  0.123  0.048  0.171
#   2.497999 -0.027 -0.057  0.576  0.549  0.252  0.453  0.129  0.057  0.180
#   2.499000 -0.024 -0.054  0.594  0.567  0.255  0.456  0.132  0.069  0.189
#   2.500000 -0.024 -0.051  0.594  0.567  0.255  0.459  0.138  0.075  0.198
#
#                V6  ...  20A_18-19  20A_19-20    aVL    aVR    aVF  \
#   0.000000 -0.018  ...      0.003      0.003  0.009 -0.042  0.033
#   0.001000 -0.018  ...      0.003      0.003  0.009 -0.042  0.033
#   0.002001 -0.018  ...     -0.003      0.006  0.006 -0.042  0.036
#   0.003001 -0.021  ...      0.003      0.003  0.006 -0.042  0.036
#   0.004002 -0.021  ...      0.003      0.003  0.006 -0.042  0.036
#   ...         ...  ...        ...        ...    ...    ...    ...
#   2.495998  0.081  ...     -0.111     -0.048  0.315  0.174 -0.492
#   2.496999  0.090  ...     -0.108     -0.045  0.312  0.168 -0.486
#   2.497999  0.099  ...     -0.114     -0.045  0.312  0.162 -0.480
#   2.499000  0.105  ...     -0.111     -0.048  0.312  0.159 -0.474
#   2.500000  0.111  ...     -0.111     -0.045  0.312  0.156 -0.471
#
#             MCC_Abl_BiPolar_1  MCC_Abl_BiPolar_2  MCC_Abl_BiPolar_3  \
#   0.000000              0.003              0.006             -0.003
#   0.001000              0.009              0.003              0.006
#   0.002001              0.009              0.006             -0.003
#   0.003001              0.012              0.006              0.000
#   0.004002              0.012              0.000              0.003
#   ...                     ...                ...                ...
#   2.495998             -0.015              0.012              0.003
#   2.496999             -0.012              0.009              0.000
#   2.497999             -0.021              0.015              0.000
#   2.499000             -0.015              0.015              0.003
#   2.500000             -0.015              0.009              0.012
#
#             MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
#   0.000000              0.003              0.000
#   0.001000              0.000             -0.006
#   0.002001              0.012             -0.009
#   0.003001             -0.012              0.012
#   0.004002              0.000              0.000
#   ...                     ...                ...
#   2.495998             -0.030              0.006
#   2.496999             -0.018             -0.006
#   2.497999             -0.018             -0.006
#   2.499000             -0.018             -0.003
#   2.500000             -0.021              0.006
#
#   [2500 rows x 59 columns]],
#  [  label_color   sample point number  \
#   0         Neg  5168113         3252
#   1         Neg  5168113         3253
#   2         Neg  5168113         3256
#   3         Neg  5168113         3257
#   4         Neg  5168113         3258
#   5         Pos  5168113         3259
#   6         Neg  5168113         3260
#   7         Pos  5168113         3261
#
#                                    file_number unipolar    bipolar         x  \
#   0  2-1-SR_PsAF_3Extra_ECG_Export_5166113.txt    20A_2    20A_1-2   9.80113
#   1  2-1-SR_PsAF_3Extra_ECG_Export_5166113.txt    20A_3    20A_3-4   6.04087
#   2  2-1-SR_PsAF_3Extra_ECG_Export_5166113.txt   20A_10   20A_9-10  -6.01098
#   3  2-1-SR_PsAF_3Extra_ECG_Export_5166113.txt   20A_11  20A_11-12  -1.19031
#   4  2-1-SR_PsAF_3Extra_ECG_Export_5166113.txt   20A_13  20A_13-14  -4.10887
#   5  2-1-SR_PsAF_3Extra_ECG_Export_5166113.txt   20A_16  20A_15-16  0.977282
#   6  2-1-SR_PsAF_3Extra_ECG_Export_5166113.txt   20A_17  20A_17-18   8.24994
#   7  2-1-SR_PsAF_3Extra_ECG_Export_5166113.txt   20A_19  20A_19-20   4.88627
#
#             y        z  refference_chanel
# ...
#   2.500000              0.018             -0.036              0.006
#
#             MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
#   0.000000             -0.024             -0.003
#   0.001000             -0.027              0.003
#   0.002001             -0.027              0.000
#   0.003001             -0.018             -0.003
#   0.004002             -0.030             -0.003
#   ...                     ...                ...
#   2.495998             -0.006              0.024
#   2.496999             -0.012              0.036
#   2.497999             -0.012              0.036
#   2.499000             -0.009              0.036
#   2.500000             -0.015              0.042
#
#   [2500 rows x 59 columns]],
#  [  label_color   sample point number  \
#   0         Neg  5805564         6921
#   1         Neg  5805564         6922
#   2         Neg  5805564         6923
#   3         Neg  5805564         6924
#   4         Neg  5805564         6925
#   5         Neg  5805564         6926
#   6         Neg  5805564         6927
#   7         Neg  5805564         6928
#   8         Neg  5805564         6929
#   9         Neg  5805564         6930
#
#                                    file_number unipolar    bipolar         x  \
#   0  2-1-SR_PsAF_3Extra_ECG_Export_5803564.txt    20A_2    20A_1-2  -31.9044
#   1  2-1-SR_PsAF_3Extra_ECG_Export_5803564.txt    20A_3    20A_3-4  -35.5721
#   2  2-1-SR_PsAF_3Extra_ECG_Export_5803564.txt    20A_5    20A_5-6  -31.1828
#   3  2-1-SR_PsAF_3Extra_ECG_Export_5803564.txt    20A_7    20A_7-8  -35.6597
#   4  2-1-SR_PsAF_3Extra_ECG_Export_5803564.txt    20A_9   20A_9-10  -28.3631
#   5  2-1-SR_PsAF_3Extra_ECG_Export_5803564.txt   20A_11  20A_11-12  -33.7859
#   6  2-1-SR_PsAF_3Extra_ECG_Export_5803564.txt   20A_13  20A_13-14  -26.6939
#   7  2-1-SR_PsAF_3Extra_ECG_Export_5803564.txt   20A_16  20A_15-16  -34.5192
#   8  2-1-SR_PsAF_3Extra_ECG_Export_5803564.txt   20A_18  20A_17-18  -31.4976
#   9  2-1-SR_PsAF_3Extra_ECG_Export_5803564.txt   20A_20  20A_19-20  -35.9787
#
#             y        z  refference_chanel
#   0  -57.0372  102.843  MCC_Abl_BiPolar_1
#   1  -52.9143  104.706  MCC_Abl_BiPolar_1
#   2  -58.4612  100.919  MCC_Abl_BiPolar_1
#   3  -52.3576  103.141  MCC_Abl_BiPolar_1
#   4  -51.5639  96.7059  MCC_Abl_BiPolar_1
#   5  -49.0507  101.934  MCC_Abl_BiPolar_1
#   6  -55.5214   105.21  MCC_Abl_BiPolar_1
#   7   -49.604  106.101  MCC_Abl_BiPolar_1
#   8  -56.8305  103.507  MCC_Abl_BiPolar_1
#   9  -51.0335  105.921  MCC_Abl_BiPolar_1  ,
#   'F:/New folder\\2-1-SR_PsAF_3Extra_ECG_Export_5803564.txt',
#                M1     M2     M3     M4     V1     V2     V3     V4     V5  \
#   0.000000 -0.048  0.123 -0.051 -0.051 -0.027  0.039  0.027  0.030  0.030
#   0.001000 -0.045  0.129 -0.048 -0.051 -0.024  0.045  0.027  0.030  0.030
#   0.002001 -0.045  0.135 -0.048 -0.051 -0.024  0.048  0.027  0.033  0.030
#   0.003001 -0.045  0.138 -0.054 -0.057 -0.024  0.048  0.027  0.033  0.030
#   0.004002 -0.042  0.141 -0.045 -0.045 -0.024  0.048  0.030  0.036  0.030
#   ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
#   2.495998  0.021 -0.015  0.114  0.087 -0.147 -0.171 -0.207 -0.066  0.015
#   2.496999  0.021 -0.015  0.114  0.087 -0.147 -0.174 -0.207 -0.066  0.018
#   2.497999  0.021 -0.015  0.117  0.087 -0.150 -0.174 -0.204 -0.063  0.018
#   2.499000  0.021 -0.015  0.126  0.096 -0.150 -0.177 -0.204 -0.063  0.021
#   2.500000  0.018 -0.015  0.126  0.093 -0.153 -0.180 -0.204 -0.063  0.024
#
#                V6  ...  20A_18-19  20A_19-20    aVL    aVR    aVF  \
#   0.000000  0.036  ...     -0.006      0.003  0.033 -0.024 -0.009
#   0.001000  0.036  ...     -0.003      0.003  0.033 -0.024 -0.009
#   0.002001  0.036  ...     -0.003      0.000  0.033 -0.027 -0.009
#   0.003001  0.036  ...      0.000      0.000  0.033 -0.027 -0.009
#   0.004002  0.033  ...     -0.003      0.000  0.033 -0.027 -0.006
#   ...         ...  ...        ...        ...    ...    ...    ...
#   2.495998  0.048  ...      0.000      0.000 -0.027 -0.066  0.093
#   2.496999  0.051  ...     -0.003     -0.003 -0.027 -0.066  0.096
#   2.497999  0.051  ...      0.003     -0.003 -0.030 -0.069  0.096
#   2.499000  0.051  ...      0.003     -0.003 -0.030 -0.069  0.099
#   2.500000  0.054  ...     -0.003      0.003 -0.030 -0.072  0.099
#
#             MCC_Abl_BiPolar_1  MCC_Abl_BiPolar_2  MCC_Abl_BiPolar_3  \
#   0.000000              0.003              0.003             -0.006
#   0.001000              0.000              0.003             -0.006
#   0.002001              0.000              0.000             -0.003
#   0.003001              0.003              0.000             -0.003
#   0.004002              0.000              0.000              0.000
#   ...                     ...                ...                ...
#   2.495998             -0.003              0.000             -0.003
#   2.496999              0.003              0.003              0.003
#   2.497999              0.003              0.006             -0.003
#   2.499000              0.000              0.003              0.000
#   2.500000              0.000              0.006              0.003
#
#             MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
#   0.000000              0.003              0.003
#   0.001000              0.003              0.003
#   0.002001             -0.003              0.003
#   0.003001              0.003              0.000
#   0.004002             -0.003              0.003
#   ...                     ...                ...
#   2.495998             -0.006              0.009
#   2.496999              0.003             -0.003
#   2.497999              0.003              0.000
#   2.499000             -0.009              0.009
#   2.500000             -0.003              0.003
#
#   [2500 rows x 59 columns]],
#  [  label_color   sample point number  \
#   0         Neg  5843019         7081
#   1         Neg  5843019         7082
#   2         Neg  5843019         7083
#   3         Neg  5843019         7084
#   4         Neg  5843019         7085
#   5         Neg  5843019         7086
#   6         Neg  5843019         7087
#   7         Neg  5843019         7088
#   8         Neg  5843019         7089
#   9         Neg  5843019         7090
#
#                                    file_number unipolar    bipolar         x  \
#   0  2-1-SR_PsAF_3Extra_ECG_Export_5841019.txt    20A_1    20A_1-2  -5.75638
#   1  2-1-SR_PsAF_3Extra_ECG_Export_5841019.txt    20A_4    20A_3-4  -15.1421
#   2  2-1-SR_PsAF_3Extra_ECG_Export_5841019.txt    20A_5    20A_5-6  -15.3347
#   3  2-1-SR_PsAF_3Extra_ECG_Export_5841019.txt    20A_8    20A_7-8  -17.8117
#   4  2-1-SR_PsAF_3Extra_ECG_Export_5841019.txt   20A_10   20A_9-10  -28.2126
#   5  2-1-SR_PsAF_3Extra_ECG_Export_5841019.txt   20A_11  20A_11-12  -23.2895
#   6  2-1-SR_PsAF_3Extra_ECG_Export_5841019.txt   20A_13  20A_13-14  -28.9781
#   7  2-1-SR_PsAF_3Extra_ECG_Export_5841019.txt   20A_15  20A_15-16  -23.0697
#   8  2-1-SR_PsAF_3Extra_ECG_Export_5841019.txt   20A_18  20A_17-18  -13.3233
#   9  2-1-SR_PsAF_3Extra_ECG_Export_5841019.txt   20A_19  20A_19-20  -15.9985
#
#             y        z  refference_chanel
#   0  -2.30984  87.6633  MCC_Abl_BiPolar_1
#   1  -4.99704  89.0173  MCC_Abl_BiPolar_1
#   2  -11.9798   78.214  MCC_Abl_BiPolar_1
#   3  -7.28205  86.1742  MCC_Abl_BiPolar_1
#   4  -10.8959   85.332  MCC_Abl_BiPolar_1
#   5  -8.10735  87.2324  MCC_Abl_BiPolar_1
#   6  -9.03361   97.632  MCC_Abl_BiPolar_1
#   7  -6.73288   92.779  MCC_Abl_BiPolar_1
#   8  -7.26283  99.3433  MCC_Abl_BiPolar_1
#   9  -5.93763  94.2551  MCC_Abl_BiPolar_1  ,
#   'F:/New folder\\2-1-SR_PsAF_3Extra_ECG_Export_5841019.txt',
#                M1     M2     M3     M4     V1     V2     V3     V4     V5  \
#   0.000000  0.144 -0.507  0.027  0.045  0.018  0.084  0.009  0.012  0.006
#   0.001000  0.144 -0.510  0.027  0.045  0.018  0.087  0.009  0.012  0.006
#   0.002001  0.141 -0.510  0.024  0.042  0.018  0.087  0.009  0.012  0.006
#   0.003001  0.144 -0.510  0.024  0.042  0.018  0.090  0.009  0.012  0.006
#   0.004002  0.144 -0.507  0.024  0.042  0.021  0.090  0.009  0.012  0.006
#   ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
#   2.495998 -0.003 -0.033  0.597  0.573  0.039  0.024  0.027  0.024  0.018
#   2.496999 -0.006 -0.033  0.600  0.576  0.042  0.024  0.024  0.024  0.021
#   2.497999 -0.006 -0.033  0.588  0.564  0.045  0.024  0.018  0.024  0.021
#   2.499000  0.000 -0.027  0.579  0.558  0.045  0.024  0.015  0.024  0.021
#   2.500000  0.003 -0.027  0.585  0.564  0.045  0.024  0.009  0.021  0.021
#
#                V6  ...  20A_18-19  20A_19-20    aVL    aVR    aVF  \
#   0.000000 -0.030  ...      0.003      0.003  0.108  0.027 -0.135
#   0.001000 -0.027  ...      0.000      0.003  0.108  0.027 -0.135
#   0.002001 -0.030  ...      0.000      0.003  0.108  0.027 -0.135
#   0.003001 -0.030  ...     -0.003      0.006  0.108  0.027 -0.135
#   0.004002 -0.030  ...      0.000      0.006  0.108  0.027 -0.132
#   ...         ...  ...        ...        ...    ...    ...    ...
#   2.495998  0.018  ...      0.006     -0.003 -0.021  0.015  0.006
#   2.496999  0.018  ...      0.003      0.000 -0.021  0.015  0.006
#   2.497999  0.018  ...     -0.003      0.000 -0.024  0.015  0.006
#   2.499000  0.018  ...     -0.009      0.003 -0.024  0.015  0.009
#   2.500000  0.015  ...     -0.003      0.000 -0.024  0.015  0.009
#
#             MCC_Abl_BiPolar_1  MCC_Abl_BiPolar_2  MCC_Abl_BiPolar_3  \
#   0.000000              0.000              0.000              0.006
#   0.001000              0.003              0.003             -0.006
#   0.002001              0.003              0.000             -0.003
#   0.003001             -0.003              0.000              0.006
#   0.004002             -0.003              0.000              0.003
#   ...                     ...                ...                ...
#   2.495998             -0.006              0.012              0.003
#   2.496999             -0.003              0.012              0.000
#   2.497999             -0.003              0.009              0.009
#   2.499000              0.000              0.009              0.009
#   2.500000             -0.003              0.003              0.006
#
#             MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
#   0.000000             -0.012              0.006
#   0.001000              0.018             -0.012
#   0.002001             -0.009              0.009
#   0.003001              0.003             -0.009
#   0.004002              0.000             -0.003
#   ...                     ...                ...
#   2.495998             -0.006              0.000
#   2.496999             -0.009              0.009
#   2.497999             -0.006             -0.003
#   2.499000             -0.012              0.003
#   2.500000              0.003             -0.009
#
#   [2500 rows x 59 columns]],
#  [  label_color   sample point number  \
#   0         Neg  5864610         7157
#   1         Neg  5864610         7158
#   2         Neg  5864610         7159
#   3         Neg  5864610         7160
#   4         Neg  5864610         7161
#   5         Neg  5864610         7162
#   6         Neg  5864610         7164
#   7         Neg  5864610         7165
#   8         Neg  5864610         7166
#
#                                    file_number unipolar    bipolar         x  \
#   0  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt    20A_2    20A_1-2  -17.0261
#   1  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt    20A_3    20A_3-4  -20.7557
#   2  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt    20A_6    20A_5-6  -12.7429
#   3  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt    20A_7    20A_7-8  -18.6578
#   4  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt   20A_10   20A_9-10  -19.7263
#   5  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt   20A_11  20A_11-12  -22.0735
#   6  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt   20A_15  20A_15-16  -29.3471
#   7  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt   20A_18  20A_17-18  -32.5567
#   8  2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt   20A_19  20A_19-20  -28.1375
#
#             y        z  refference_chanel
#   0  -32.7324  75.6138  MCC_Abl_BiPolar_1
#   1  -37.4244  75.6966  MCC_Abl_BiPolar_1
#   2  -43.5187  76.8624  MCC_Abl_BiPolar_1
#   3  -42.6501  76.4138  MCC_Abl_BiPolar_1
#   4   -52.065  79.0883  MCC_Abl_BiPolar_1
#   5  -46.8577  77.3007  MCC_Abl_BiPolar_1
#   6  -43.8266  75.5485  MCC_Abl_BiPolar_1
#   7  -34.0192  74.6287  MCC_Abl_BiPolar_1
#   8  -38.0366  75.0998  MCC_Abl_BiPolar_1  ,
#   'F:/New folder\\2-1-SR_PsAF_3Extra_ECG_Export_5862610.txt',
#                M1     M2     M3     M4     V1     V2     V3     V4     V5  \
#   0.000000  0.237 -0.078  0.120  0.138  0.009 -0.015  0.006  0.006  0.006
#   0.001000  0.231 -0.084  0.120  0.141  0.009 -0.012  0.003  0.003  0.006
#   0.002001  0.222 -0.090  0.117  0.138  0.009 -0.006  0.003  0.003  0.003
#   0.003001  0.216 -0.099  0.111  0.135  0.009 -0.003  0.003  0.000  0.003
#   0.004002  0.216 -0.102  0.114  0.138  0.012  0.003  0.003  0.000  0.003
#   ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
#   2.495998  0.021 -0.015  0.027  0.024  0.015  0.012  0.027 -0.021 -0.018
#   2.496999  0.021 -0.012  0.027  0.024  0.015  0.012  0.024 -0.021 -0.018
#   2.497999  0.018 -0.015  0.027  0.021  0.012  0.012  0.021 -0.021 -0.015
#   2.499000  0.015 -0.015  0.024  0.021  0.012  0.012  0.018 -0.021 -0.015
#   2.500000  0.015 -0.015  0.030  0.024  0.012  0.009  0.015 -0.021 -0.015
#
#                V6  ...  20A_18-19  20A_19-20    aVL    aVR    aVF  \
#   0.000000  0.000  ...      0.000      0.003  0.015  0.006 -0.021
#   0.001000  0.003  ...     -0.003      0.000  0.015  0.006 -0.021
#   0.002001  0.003  ...      0.000      0.000  0.015  0.006 -0.021
#   0.003001  0.003  ...     -0.006      0.006  0.015  0.006 -0.021
#   0.004002  0.006  ...     -0.003      0.000  0.012  0.006 -0.018
#   ...         ...  ...        ...        ...    ...    ...    ...
#   2.495998 -0.030  ...     -0.003     -0.003 -0.039 -0.072  0.111
#   2.496999 -0.027  ...     -0.003      0.003 -0.039 -0.072  0.111
#   2.497999 -0.024  ...      0.000      0.003 -0.039 -0.072  0.111
#   2.499000 -0.024  ...     -0.006      0.003 -0.039 -0.072  0.111
#   2.500000 -0.024  ...      0.000      0.000 -0.039 -0.072  0.111
#
#             MCC_Abl_BiPolar_1  MCC_Abl_BiPolar_2  MCC_Abl_BiPolar_3  \
#   0.000000             -0.012              0.003              0.000
#   0.001000             -0.018              0.000             -0.003
#   0.002001             -0.015             -0.003              0.009
#   0.003001             -0.018              0.000              0.000
#   0.004002             -0.018             -0.003              0.003
#   ...                     ...                ...                ...
#   2.495998              0.000              0.000              0.000
#   2.496999              0.000              0.000             -0.003
#   2.497999             -0.003              0.000              0.000
#   2.499000              0.000              0.000              0.003
#   2.500000              0.003              0.000             -0.006
#
#             MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
#   0.000000              0.003             -0.003
#   0.001000              0.000              0.003
#   0.002001              0.000             -0.009
#   0.003001             -0.003              0.003
#   0.004002              0.000             -0.003
#   ...                     ...                ...
#   2.495998              0.003             -0.003
#   2.496999             -0.003              0.006
#   2.497999             -0.006              0.006
#   2.499000              0.000              0.000
#   2.500000             -0.006              0.009
#
#   [2500 rows x 59 columns]]]

# %%
"""car file data for each signal file"""
sig[1][0]
# Out:
#   label_color   sample point number  \
# 0         Neg  4881543          885
# 1         Neg  4881543          886
# 2         Neg  4881543          887
# 3         Neg  4881543          888
# 4         Neg  4881543          889
# 5         Neg  4881543          890
# 6         Pos  4881543          891
# 7         Pos  4881543          892
# 8         Pos  4881543          893
# 9         Pos  4881543          894
#
#                                  file_number unipolar    bipolar         x  \
# 0  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt    20A_2    20A_1-2  -13.1371
# 1  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt    20A_3    20A_3-4  -17.9368
# 2  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt    20A_5    20A_5-6  -10.4747
# 3  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt    20A_7    20A_7-8  -17.4159
# 4  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt   20A_10   20A_9-10  -24.1159
# 5  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt   20A_12  20A_11-12  -22.9175
# 6  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt   20A_14  20A_13-14  -33.4287
# 7  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt   20A_15  20A_15-16  -27.6849
# 8  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt   20A_17  20A_17-18  -24.9949
# 9  2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt   20A_20  20A_19-20  -23.4032
#
#           y        z  refference_chanel
# 0  -18.0803  77.5021  MCC_Abl_BiPolar_1
# 1  -21.5291  76.5117  MCC_Abl_BiPolar_1
# 2  -31.4276  76.0026  MCC_Abl_BiPolar_1
# 3  -27.4644  76.1823  MCC_Abl_BiPolar_1
# 4  -36.3351  76.0792  MCC_Abl_BiPolar_1
# 5  -28.5506  76.2769  MCC_Abl_BiPolar_1
# 6  -27.0908  73.3042  MCC_Abl_BiPolar_1
# 7  -25.9844   74.605  MCC_Abl_BiPolar_1
# 8  -12.6322  80.2767  MCC_Abl_BiPolar_1
# 9  -21.4197  76.6981  MCC_Abl_BiPolar_1

# %%
"""signal data"""
sig[1][2]
# Out:
#              M1     M2     M3     M4     V1     V2     V3     V4     V5  \
# 0.000000  0.066  0.234  0.084  0.060 -0.039  0.015  0.087  0.069  0.072
# 0.001000  0.075  0.246  0.081  0.057 -0.042  0.018  0.090  0.069  0.075
# 0.002001  0.081  0.252  0.096  0.066 -0.042  0.021  0.090  0.072  0.075
# 0.003001  0.087  0.261  0.105  0.075 -0.042  0.024  0.093  0.072  0.078
# 0.004002  0.096  0.273  0.102  0.072 -0.042  0.027  0.093  0.075  0.081
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2.495998  0.012 -0.021  0.096  0.069 -0.135 -0.030 -0.069  0.042  0.111
# 2.496999  0.012 -0.018  0.099  0.069 -0.129 -0.027 -0.069  0.045  0.114
# 2.497999  0.012 -0.018  0.093  0.063 -0.123 -0.024 -0.066  0.048  0.114
# 2.499000  0.009 -0.021  0.087  0.057 -0.114 -0.021 -0.066  0.051  0.117
# 2.500000  0.006 -0.021  0.090  0.063 -0.108 -0.018 -0.069  0.051  0.117
#
#              V6  ...  20A_18-19  20A_19-20    aVL    aVR    aVF  \
# 0.000000  0.057  ...      0.000      0.000 -0.060 -0.057  0.117
# 0.001000  0.057  ...      0.000      0.000 -0.060 -0.060  0.120
# 0.002001  0.057  ...      0.000     -0.003 -0.063 -0.060  0.123
# 0.003001  0.057  ...     -0.003      0.000 -0.063 -0.060  0.123
# 0.004002  0.057  ...      0.000     -0.003 -0.063 -0.060  0.123
# ...         ...  ...        ...        ...    ...    ...    ...
# 2.495998  0.102  ...      0.000      0.003  0.015 -0.072  0.060
# 2.496999  0.102  ...     -0.006      0.003  0.015 -0.075  0.060
# 2.497999  0.102  ...      0.003      0.000  0.015 -0.075  0.060
# 2.499000  0.102  ...     -0.003      0.003  0.018 -0.075  0.057
# 2.500000  0.102  ...     -0.003      0.003  0.018 -0.075  0.054
#
#           MCC_Abl_BiPolar_1  MCC_Abl_BiPolar_2  MCC_Abl_BiPolar_3  \
# 0.000000              0.000              0.003             -0.006
# 0.001000              0.000              0.012              0.000
# 0.002001              0.000              0.009              0.000
# 0.003001             -0.003              0.006             -0.006
# 0.004002              0.003              0.009              0.000
# ...                     ...                ...                ...
# 2.495998              0.000             -0.003             -0.006
# 2.496999             -0.003              0.003              0.000
# 2.497999              0.003             -0.003              0.003
# 2.499000             -0.003             -0.003              0.000
# 2.500000              0.000             -0.003              0.000
#
#           MCC_Abl_BiPolar_4  MCC_Abl_BiPolar_5
# 0.000000             -0.003              0.006
# 0.001000              0.006             -0.009
# 0.002001              0.003              0.000
# 0.003001              0.006              0.000
# 0.004002             -0.009              0.009
# ...                     ...                ...
# 2.495998              0.006             -0.003
# 2.496999             -0.003              0.003
# 2.497999              0.000             -0.006
# 2.499000             -0.003              0.003
# 2.500000             -0.006              0.006
#
# [2500 rows x 59 columns]

# %%
"""the file that the signal is exported from"""
print(sig[1][1])
# Out:
# F:/New folder\2-1-SR_PsAF_3Extra_ECG_Export_4879543.txt

# %%
"""summary of files asociated with the selected map name"""
carto.files_cat()
# Out:
# [('2-1-SR_PsAF_3Extra.mesh', 1),
#  ('2-1-SR_PsAF_3Extra_car.txt', 1),
#  ('2-1-SR_PsAF_3Extra_DEC_CONNECTOR_Eleclectrode_Positions_.txt', 26),
#  ('2-1-SR_PsAF_3Extra_DEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt',
#   26),
#  ('2-1-SR_PsAF_3Extra_ECG_Export_.txt', 29),
#  ('2-1-SR_PsAF_3Extra_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_.txt',
#   29),
#  ('2-1-SR_PsAF_3Extra_MAGNETIC_20_POLE_A_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt',
#   29),
#  ('2-1-SR_PsAF_3Extra_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_.txt', 29),
#  ('2-1-SR_PsAF_3Extra_MAGNETIC_20_POLE_A_CONNECTOR_Sensor_Positions_OnAnnotation_.txt',
#   29),
#  ('2-1-SR_PsAF_3Extra_MEC_CONNECTOR_Eleclectrode_Positions_.txt', 29),
#  ('2-1-SR_PsAF_3Extra_MEC_CONNECTOR_Eleclectrode_Positions_OnAnnotation_.txt',
#   29),
#  ('2-1-SR_PsAF_3Extra_MEC_CONNECTOR_Sensor_Positions_.txt', 29),
#  ('2-1-SR_PsAF_3Extra_MEC_CONNECTOR_Sensor_Positions_OnAnnotation_.txt', 29),
#  ('2-1-SR_PsAF_3Extra_P_Point_Export.xml', 284),
#  ('2-1-SR_PsAF_3Extra_Points_Export.xml', 1)]

# %%
"""summary of files that are not asociated to any map names"""
carto.files_cat(exclusive=True)
# Out:
# [('2-1-1-1-RequemarAI.mesh', 1),
#  ('2-1-1-1-RequemarAI_car.txt', 1),
#  ('2-1-1-1-RequemarAI_Points_Export.xml', 1),
#  ('2-1-1-quemarAI.mesh', 1),
#  ('2-1-1-quemarAI_car.txt', 1),
#  ('2-1-1-quemarAI_Points_Export.xml', 1),
#  ('3-ev_car.txt', 1),
#  ('3-ev_Points_Export.xml', 1),
#  ('Aorta.mesh', 1),
#  ('APAData.txt', 1),
#  ('ContactForceInRF_2-1-1-1-RequemarAI_.txt', 64),
#  ('Esofa.mesh', 1),
#  ('Export_Study-1-10_24_2024-15-29-43.zip', 1),
#  ('LA.mesh', 1),
#  ('LAWT.mesh', 1),
#  ('LAWT.vtk', 1),
#  ('LA_Endo.vtk', 1),
#  ('LA_Epi.vtk', 1),
#  ('LA_Print_esfogao.mesh', 1),
#  ('LV.mesh', 1),
#  ('Orejuela.mesh', 1),
#  ('Orejuela.vtk', 1),
#  ('PA.mesh', 1),
#  ('RA.mesh', 1),
#  ('RA.vtk', 1),
#  ('RF_2-1-1-1-RequemarAI_.txt', 64),
#  ('RF_CARTO_TO_ABLATOR_SESSIONS_MAPPING.txt', 1),
#  ('RV.mesh', 1),
#  ('Study 1 10_24_2024 15-29-43.xml', 1),
#  ('TemperaturesInRF_2-1-1-1-RequemarAI_.txt', 64),
#  ('Version.txt', 1)]

# %%
"""extracting mesh data for the selected map name; vertices, faces, unipolar, and bipolar values """
carto.pars_mesh_file_with_electrode()
# Out:
# (array([[-56.981, -42.242,  59.525],
#         [-57.643, -41.573,  59.295],
#         [-56.876, -41.656,  59.257],
#         ...,
#         [-24.441, -15.426, 113.784],
#         [-25.267, -15.366, 113.675],
#         [-25.927, -15.259, 113.601]]),
#  array([[    3,     1,     0],
#         [    4,     2,     1],
#         [    5,     0,     2],
#         ...,
#         [30005, 30001, 29996],
#         [29998, 30005, 30004],
#         [30001, 30005, 30002]]),
#  array([10000., 10000., 10000., ..., 10000., 10000., 10000.]),
#  array([10000., 10000., 10000., ..., 10000., 10000., 10000.]))

# %%
print(carto.unipolar,carto.bipolar)
# Out:
# [10000. 10000. 10000. ... 10000. 10000. 10000.] [10000. 10000. 10000. ... 10000. 10000. 10000.]

# %%
"""vertices and faces in a friendly format forpyvista library"""
carto.mesh_build()
# Out:
# [array([[-56.981, -42.242,  59.525],
#         [-57.643, -41.573,  59.295],
#         [-56.876, -41.656,  59.257],
#         ...,
#         [-24.441, -15.426, 113.784],
#         [-25.267, -15.366, 113.675],
#         [-25.927, -15.259, 113.601]]),
#  array([    3,     3,     1, ..., 30001, 30005, 30002])]

# %%
print(carto.color_dict)
# Out:
# {'25': 'Neg', '26': 'Pos'}

# %%
carto.extracting_color_coding(triple=False)
# Out:
# [{'Radius': '2',
#   'Color': '1 1 1 1',
#   'Full_Name': 'None',
#   'Short_Name': 'None',
#   'Tag ID': '4'},
#  {'Radius': '2',
#   'Color': '0.298039 0.239216 0.819608 1',
#   'Full_Name': 'LSPV OS',
#   'Short_Name': 'LSPV OS',
#   'Tag ID': '201'},
#  {'Radius': '2',
#   'Color': '0.517647 0 0 1',
#   'Full_Name': 'Ablation',
#   'Short_Name': 'ABL',
#   'Tag ID': '9'},
#  {'Radius': '2',
#   'Color': '0.937255 0.709804 0.129412 1',
#   'Full_Name': 'His',
#   'Short_Name': 'HIS',
#   'Tag ID': '5'},
#  {'Radius': '2',
#   'Color': '0.776471 0.776471 0 1',
#   'Full_Name': 'Pacing Site',
#   'Short_Name': 'PS',
#   'Tag ID': '6'},
#  {'Radius': '2',
#   'Color': '0.501961 0 1 1',
#   'Full_Name': 'RMPV_AC',
#   'Short_Name': 'RMPV_AC',
#   'Tag ID': '312'},
#  {'Radius': '2',
#   'Color': '0 0.776471 0.776471 1',
#   'Full_Name': 'Double Potential',
#   'Short_Name': 'DP',
#   'Tag ID': '7'},
#  {'Radius': '2',
#   'Color': '1 0.776471 1 1',
#   'Full_Name': 'Fragmented Signal',
#   'Short_Name': 'FS',
#   'Tag ID': '8'},
#  {'Radius': '2',
#   'Color': '0.0235294 0.839216 0.819608 1',
#   'Full_Name': 'LIPV OS',
#   'Short_Name': 'LIPV OS',
#   'Tag ID': '200'},
#  {'Radius': '2',
#   'Color': '0.419608 0.388235 0.388235 1',
#   'Full_Name': 'Scar',
#   'Short_Name': 'SCR',
#   'Tag ID': '10'},
#  {'Radius': '2',
#   'Color': '0.764706 0.768627 0.0313726 1',
#   'Full_Name': 'RIPV OS',
#   'Short_Name': 'RIPV OS',
#   'Tag ID': '202'},
#  {'Radius': '2',
#   'Color': '0.756863 0.929412 0.647059 1',
#   'Full_Name': 'Location Only',
#   'Short_Name': 'LO',
#   'Tag ID': '11'},
#  {'Radius': '2',
#   'Color': '0.603922 0.309804 0.0235294 1',
#   'Full_Name': 'RSPV OS',
#   'Short_Name': 'RSPV OS',
#   'Tag ID': '203'},
#  {'Radius': '2',
#   'Color': '0.752941 1 1 1',
#   'Full_Name': 'LIPV',
#   'Short_Name': 'LIPV',
#   'Tag ID': '100'},
#  {'Radius': '2',
#   'Color': '0.619608 0.584314 0.968627 1',
#   'Full_Name': 'LSPV',
#   'Short_Name': 'LSPV',
#   'Tag ID': '101'},
#  {'Radius': '2',
#   'Color': '1 1 0.501961 1',
#   'Full_Name': 'RIPV',
#   'Short_Name': 'RIPV',
#   'Tag ID': '102'},
#  {'Radius': '2',
#   'Color': '0 0.501961 0.752941 1',
#   'Full_Name': 'Used Frame',
#   'Short_Name': 'UF',
#   'Tag ID': '301'},
#  {'Radius': '2',
#   'Color': '1 0.501961 0 1',
#   'Full_Name': 'RSPV',
#   'Short_Name': 'RSPV',
#   'Tag ID': '103'},
#  {'Radius': '2',
#   'Color': '0.603922 0.0235294 0.47451 1',
#   'Full_Name': 'IVC OS',
#   'Short_Name': 'IVC OS',
#   'Tag ID': '204'},
#  {'Radius': '2',
#   'Color': '0.0352941 0.588235 0.235294 1',
#   'Full_Name': 'SVC OS',
#   'Short_Name': 'SVC OS',
#   'Tag ID': '205'},
#  {'Radius': '2',
#   'Color': '0 0 1 1',
#   'Full_Name': 'End of Sheath',
#   'Short_Name': 'EOS',
#   'Tag ID': '13'},
#  {'Radius': '2',
#   'Color': '0.92549 0.784314 0.788235 1',
#   'Full_Name': 'CS OS',
#   'Short_Name': 'CS OS',
#   'Tag ID': '206'},
#  {'Radius': '2',
#   'Color': '0.517647 0 0 1',
#   'Full_Name': 'QMODE+ Ablation',
#   'Short_Name': 'QM+',
#   'Tag ID': '14'},
#  {'Radius': '2',
#   'Color': '1 1 1 1',
#   'Full_Name': 'Mitral Annulus',
#   'Short_Name': 'MA',
#   'Tag ID': '104'},
#  {'Radius': '2',
#   'Color': '0.337255 0.411765 0.356863 1',
#   'Full_Name': 'ESOPHAGUS',
#   'Short_Name': 'ESO',
#   'Tag ID': '311'},
#  {'Radius': '2',
#   'Color': '0 0.501961 1 1',
#   'Full_Name': 'Tricuspid Annulus',
#   'Short_Name': 'TA',
#   'Tag ID': '105'},
#  {'Radius': '1',
#   'Color': '0 0.501961 0 1',
#   'Full_Name': 'Complex.Frac',
#   'Short_Name': 'C.Frac',
#   'Tag ID': '51'},
#  {'Radius': '2',
#   'Color': '0.337255 0.411765 0.356863 1',
#   'Full_Name': 'ACESOPHAGUS',
#   'Short_Name': 'ACESOPH',
#   'Tag ID': '308'},
#  {'Radius': '2',
#   'Color': '0.501961 1 1 1',
#   'Full_Name': 'CLIP',
#   'Short_Name': 'CLIP',
#   'Tag ID': '500'},
#  {'Radius': '2',
#   'Color': '0.517647 0 0 1',
#   'Full_Name': 'RF Balloon Ablation',
#   'Short_Name': 'RF Ball',
#   'Tag ID': '15'},
#  {'Radius': '2',
#   'Color': '0.501961 1 1 1',
#   'Full_Name': 'New Frame',
#   'Short_Name': 'NF',
#   'Tag ID': '300'},
#  {'Radius': '2',
#   'Color': '0.501961 0.501961 0 1',
#   'Full_Name': 'LA_AC',
#   'Short_Name': 'LA_AC',
#   'Tag ID': '302'},
#  {'Radius': '2',
#   'Color': '0.25098 0 0.25098 1',
#   'Full_Name': 'LAA_AC',
#   'Short_Name': 'LAA_AC',
#   'Tag ID': '303'},
#  {'Radius': '2',
#   'Color': '0.752941 1 1 1',
#   'Full_Name': 'LIPV_AC',
#   'Short_Name': 'LIPV_AC',
#   'Tag ID': '304'},
#  {'Radius': '2',
#   'Color': '0.619608 0.584314 0.968627 1',
#   'Full_Name': 'LSPV_AC',
#   'Short_Name': 'LSPV_AC',
#   'Tag ID': '305'},
#  {'Radius': '2',
#   'Color': '1 1 0.501961 1',
#   'Full_Name': 'RIPV_AC',
#   'Short_Name': 'RIPV_AC',
#   'Tag ID': '306'},
#  {'Radius': '2',
#   'Color': '1 0.501961 0 1',
#   'Full_Name': 'RSPV_AC',
#   'Short_Name': 'RSPV_AC',
#   'Tag ID': '307'},
#  {'Radius': '2',
#   'Color': '0.501961 0.501961 0 1',
#   'Full_Name': 'LA',
#   'Short_Name': 'LA',
#   'Tag ID': '309'},
#  {'Radius': '2',
#   'Color': '0.25098 0 0.25098 1',
#   'Full_Name': 'LAA',
#   'Short_Name': 'LAA',
#   'Tag ID': '310'},
#  {'Radius': '2',
#   'Color': '1 0.501961 0 1',
#   'Full_Name': 'Neg',
#   'Short_Name': 'Neg',
#   'Tag ID': '25'},
#  {'Radius': '2',
#   'Color': '0 1 0 1',
#   'Full_Name': 'Pos',
#   'Short_Name': 'Pos',
#   'Tag ID': '26'},
#  {'Radius': '2',
#   'Color': '0.501961 0 1 1',
#   'Full_Name': 'RMPV',
#   'Short_Name': 'RMPV',
#   'Tag ID': '313'},
#  {'Radius': '2',
#   'Color': '0 1 0 1',
#   'Full_Name': 'LCPV_AC',
#   'Short_Name': 'LCPV_AC',
#   'Tag ID': '314'},
#  {'Radius': '2',
#   'Color': '0 1 0 1',
#   'Full_Name': 'LCPV',
#   'Short_Name': 'LCPV',
#   'Tag ID': '315'},
#  {'Radius': '2',
#   'Color': '0.192157 0.0823529 0.278431 1',
#   'Full_Name': 'PF Ablation',
#   'Short_Name': 'PFA ABL',
#   'Tag ID': '16'},
#  {'Radius': '2',
#   'Color': '0 0.501961 0.25098 1',
#   'Full_Name': 'Doubts',
#   'Short_Name': 'Dou',
#   'Tag ID': '27'}]

# %%
print(carto.color_dict)
# Out:
# {'4': 'None', '201': 'LSPV OS', '9': 'Ablation', '5': 'His', '6': 'Pacing Site', '312': 'RMPV_AC', '7': 'Double Potential', '8': 'Fragmented Signal', '200': 'LIPV OS', '10': 'Scar', '202': 'RIPV OS', '11': 'Location Only', '203': 'RSPV OS', '100': 'LIPV', '101': 'LSPV', '102': 'RIPV', '301': 'Used Frame', '103': 'RSPV', '204': 'IVC OS', '205': 'SVC OS', '13': 'End of Sheath', '206': 'CS OS', '14': 'QMODE+ Ablation', '104': 'Mitral Annulus', '311': 'ESOPHAGUS', '105': 'Tricuspid Annulus', '51': 'Complex.Frac', '308': 'ACESOPHAGUS', '500': 'CLIP', '15': 'RF Balloon Ablation', '300': 'New Frame', '302': 'LA_AC', '303': 'LAA_AC', '304': 'LIPV_AC', '305': 'LSPV_AC', '306': 'RIPV_AC', '307': 'RSPV_AC', '309': 'LA', '310': 'LAA', '25': 'Neg', '26': 'Pos', '313': 'RMPV', '314': 'LCPV_AC', '315': 'LCPV', '16': 'PF Ablation', '27': 'Doubts'}
